# %% [markdown]
# ## Importing the necessary packages

# %%
import spacy
nlp2 = spacy.load("en_core_web_lg")
import requests
from bs4 import BeautifulSoup
import itertools
from spacy.lang.en.stop_words import STOP_WORDS
from nltk.sentiment.vader import SentimentIntensityAnalyzer as SIA
import nltk
nltk.download('vader_lexicon')

# %% [markdown]
# # MAIN

# %% [markdown]
# # Text Analysis

# %% [markdown]
# ## Objective
#
# Using Python programming language and any publicly available libraries analyze articles in Yahoo!Finance area (https://finance.yahoo.com/). The code should be able to process any article from available current set

# %% [markdown]
# #### Assumption:
#  - For simplicity extracting only the main page list of articles, with no scrolling down the page

# %%
url = 'https://finance.yahoo.com'

# Extracting articles from yahoo finance by using the function 'get_article_content(url)'
new_content = get_article_content(url)

# %% [markdown]
# # 1. Named Entity Extraction
#
# Extract all available entities (person names, organizations, locations, medical codes, time expressions, quantities, monetary values, percentages, etc). Build Key/Value pairs for numeric values (quantities, monetary values etc) - for example: revenue =  $123,456. Build weight of each "key" based on frequency of appearance in currently analyzed articles.

# %% [markdown]
# ### 1.1. Displaying extracted articles with founded entities

# %%
display_articles_and_entities(new_content)
# Out:
# TITLE: Amazon Tells Echelon Fitness to Stop Selling $500 Prime Bike
# -------------------------------------------------------------------------------------------------------
#
# CONTENT:
# -------------------------------------------------------------------------------------------------------
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">(
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bloomberg
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ) --
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Amazon.com Inc.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  told
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Echelon Fitness
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  to stop selling an exercise bike that was promoted and branded as a product developed in partnership with the e-commerce giant.</br>
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Echelon
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  announced the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     EX
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# -Prime Smart Connect Bike
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     earlier this week
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  and said it was developed “in collaboration with
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Amazon
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# .” The machine was listed on
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Amazon
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ’s website for $
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     500
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
# , a steep discount to machines offered by
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Peloton Interactive Inc.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>“This bike is not an
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Amazon
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  product or related to
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Amazon
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  Prime,” an
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Amazon
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  spokeswoman wrote in an email
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     late Tuesday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# . “
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Echelon
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  does not have a formal partnership with
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Amazon
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# . We are working with
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Echelon
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  to clarify this in its communications, stop the sale of the product, and change the product branding.”</br>
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Amazon
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ’s Prime subscription, which offers free shipping and other perks for an
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     annual
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  fee, has been one of the most successful offerings in e-commerce history. Products associated with the program often get a sales boost, especially on
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Amazon
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ’s website.</br>
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Echelon
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  didn’t immediately respond to a request for comment. However, the company’s original press release announcing the bike was no longer available online
# <m
# TITLE: 3 “Strong Buy” Stocks That Are Flirting With a Bottom
# -------------------------------------------------------------------------------------------------------
#
# CONTENT:
# -------------------------------------------------------------------------------------------------------
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">In the investing game, it’s not only about what you buy; it’s about when you buy it.
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     One
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  of the most common pieces of advice thrown around the Street, “buy low” is touted as a tried-and-true tactic.</br>Sure, the strategy seems simple. Stock prices naturally fluctuate on the basis of several factors like earnings results and the macro environment, amongst others, with investors trying to time the market and determine when stocks have hit a bottom. In practice, however, executing on this strategy is no easy task.</br>On top of this, given the volatility that has ruled the markets over
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the last few weeks
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , how are investors supposed to gauge when a name is flirting with a bottom? That’s where the Wall Street pros come in.</br>These expert stock pickers have identified
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     three
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  compelling tickers whose current share prices land close to their
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     52-week
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  lows. Noting that each is set to take back off on an upward trajectory, the analysts see an attractive entry point. Using TipRanks’ database, we found out that the analyst consensus has rated all
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     three
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  a Strong Buy, with major upside potential also on tap.</br>
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Progenity
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  (PROG)</br>Offering clear and actionable genetic results,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Progenity
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  specializes in providing testing services. The company started trading on
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Nasdaq
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     June
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  and saw its shares tumbling
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     44%
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
#  since then. With shares changing hands for $
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     8.11
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
# , several members of the Street recommend pulling the trigger before it heats up.</br>
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Piper Sandler
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  analyst
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Steven Mah
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  points out that even against the backdrop of COVID-19, PROG managed to deliver with its
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Q2 2020
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  performance. “We are encouraged by the recovery in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     late Q2 2020
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  with
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     75,000
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  accessioned tests (~79,000 in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Q1 2020
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ), driven by noninvasive prenatal testing (NIPT) and carrier screening,” the analyst noted.</br>Expounding on this,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mah
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  stated, “
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Progenity
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; ve
# TITLE: Tesla’s Battery Day Letdown Risks $320 Billion Stock Gain
# -------------------------------------------------------------------------------------------------------
#
# CONTENT:
# -------------------------------------------------------------------------------------------------------
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">(
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bloomberg
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ) --
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tesla Inc.’s
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  highly anticipated “
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Battery Day
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
# ” fell short of expectations that helped fuel its
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     $320 billion
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  surge in market value
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     this year
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , with
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Elon Musk
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  outlining grandiose goals that will take time to pull off.</br>The chief executive officer laid out a plan
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tuesday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  to build a $
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     25,000
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  car and cut battery costs in
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     half
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  over
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the next three years
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# . Analysts said while the technology and manufacturing innovations outlined were impressive,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tesla
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ’s valuation already reflected its ability to disrupt and that investors may be let down by the lack of surprises at the much-hyped event.</br>“With the Battery Day in the rearview, we think there is a lack of upcoming catalysts and are cautious about demand given the recessionary environment,”
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Robert W. Baird
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ’s
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ben Kallo
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  wrote in a
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Wednesday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  report naming
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tesla
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  a bearish “fresh pick.”</br>That was echoed by
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Patrick Hummel
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , an analyst at
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     UBS
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  with a “neutral” rating on the stock, who said in a research note
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tesla
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ’s leadership in battery technology and costs is fully valued into the stock. “Given the high expectations into the event, we think the market will initially respond negatively to the relatively long timelines of the innovations and the lack of granularity,” he wrote.</br>
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tesla
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  shares fell
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     5.4%
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
#  to $
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     401.19
#     <span style="font-size: 0.
# TITLE: Tesla rival? Bill Gates-backed electric vehicle battery startup comes into limelight
# -------------------------------------------------------------------------------------------------------
#
# CONTENT:
# -------------------------------------------------------------------------------------------------------
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">A
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     $4.3 billion
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bill Gates
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# -backed electric vehicle battery startup called
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     QuantumScape
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  could rival
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tesla
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , according to a
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Monday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  report from
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Medium Editor
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# -at-Large
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Steve LeVine
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# .</br>The
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     10-year-old
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     California
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  startup, also backed by
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Volkswagen AG
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , announced on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Sept. 3
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  that it will be going public on
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the New York Stock Exchange
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  under the ticker &quot;QS&quot; after merging with shell company
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Kensington Capital Acquisition Corp
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Reuters
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  reported at the time.</br>&quot;Our ambition is to be a [battery] supplier to the industry as a whole,&quot;
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     QuantumScape
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  founder and CEO
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Jagdeep Singh
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  told the outlet.</br>The battery maker raised
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     more than $500 million
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  from investors led by
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Fidelity Management
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  and Research ahead of the merger,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Reuters
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  reported.
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Volkswagen
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  has invested a total of
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     $300 million
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  in QuantumScape with the goal of starting a production line for the startup's batteries by
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2025
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercas

# %% [markdown]
# ### 1.2. Displaying some entity statistics:

# %%
# Extracting all named entiites and their statistics by using the functions 'entities_and_statistics(contents)''
all_entities, entity_type_frequency, entity_frequency, entity_occurence_percent = entities_and_statistics(new_content)

# Displaying the results with the function 'display_entity_statistics(p1, p2, p3, p4)'
display_entity_statistics(all_entities, entity_type_frequency, entity_frequency, entity_occurence_percent)
# Out:
# ENTITY STATISTICS:
#
#
# Total entities: 402
# -------------------------------------------------------------------------------------------------------
# Total unique entites: 246
# -------------------------------------------------------------------------------------------------------
#
#
# Top 10 entity occurrences:
# -------------------------------------------------------------------------------------------------------
# Tesla : 27
# Musk : 14
# QURE : 11
# Amazon : 10
# TCMD : 9
# Progenity : 8
# Echelon : 6
# Mah : 5
# Furlong : 5
# Schwartz : 5
#
#
# Top 10 entity occurrences in percentage:
# -------------------------------------------------------------------------------------------------------
# Tesla : 7.000000000000001%
# Musk : 3.0%
# QURE : 3.0%
# Amazon : 2.0%
# TCMD : 2.0%
# Progenity : 2.0%
# Echelon : 1.0%
# Mah : 1.0%
# Furlong : 1.0%
# Schwartz : 1.0%
#
#
# Entity type frequency:
# -------------------------------------------------------------------------------------------------------
# ORG (Companies, agencies, institutions, etc.) : 159
# DATE (Absolute or relative dates or periods) : 79
# PERSON (People, including fictional) : 45
# MONEY (Monetary values, including unit) : 30
# PERCENT (Percentage, including "%") : 24
# CARDINAL (Numerals that do not fall under another type) : 20
# GPE (Countries, cities, states) : 15
# PRODUCT (Objects, vehicles, foods, etc. (not services)) : 10
# ORDINAL ("first", "second", etc.) : 4
# EVENT (Named hurricanes, battles, wars, sports events, etc.) : 4
# WORK_OF_ART (Titles of books, songs, etc.) : 3
# TIME (Times smaller than a day) : 3
# QUANTITY (Measurements, as of weight or distance) : 3
# NORP (Nationalities or religious or political groups) : 2
# FAC (Buildings, airports, highways, bridges, etc.) : 1

# %% [markdown]
# ### 1.3. Displaying w Key/Value pairs statistics:

# %%
key_value_pairs, key_weights_percent, key_weights, total_keys = generic_overview_num_values(new_content)
display_key_value_statistics(key_value_pairs, key_weights_percent, key_weights, total_keys)
# Out:
# NUMERIC KEY/VALUE STATISTICS:
#
#
# Total keys/values: 113
# -------------------------------------------------------------------------------------------------------
# Total unique keys: 77
# -------------------------------------------------------------------------------------------------------
#
#
# Top 10 key occurrences:
# -------------------------------------------------------------------------------------------------------
# year : 11
# million : 8
# billion : 5
# target : 4
# kWh : 3
# bike : 2
# © : 2
# Q1 : 2
# volumes : 2
# Buys : 2
#
#
# Top 10 key occurrences in percentage:
# -------------------------------------------------------------------------------------------------------
# year : 10.0%
# million : 7.000000000000001%
# billion : 4.0%
# target : 4.0%
# kWh : 3.0%
# bike : 2.0%
# © : 2.0%
# Q1 : 2.0%
# volumes : 2.0%
# Buys : 2.0%

# %% [markdown]
# ### 1.4. Displaying Sentence Dependency for choosen key word == 'target'

# %%
# Choosed key word from top 10 key occurrences
key_word = 'target'

sentences = key_word_sents(new_content, key_word)
display_sentence_dependency(sentences)
# Out:
# Sentence:
# -------------------------------------------------------------------------------------------------------
# To this end, Mah rates PROG an Overweight (i.e. Buy) along with a $17 price target.
#
# Sentence Dependency:
# -------------------------------------------------------------------------------------------------------
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="44b1d482089841e0908ec5fb5eba9b1e-0" class="displacy" width="1750" height="437.0" direction="ltr" style="max-width: none; height: 437.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">To</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="150">this</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="150">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="250">end,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="250">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">Mah</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="450">rates</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="450">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="550">PROG</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="550">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">an</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">Overweight (</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="850">i.e.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="850">X</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">Buy)</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1050">along</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1050">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1150">with</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1150">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1350">$</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1350">SYM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">17</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1550">price</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1550">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1650">target.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1650">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-44b1d482089841e0908ec5fb5eba9b1e-0-0" stroke-width="2px" d="M70,302.0 C70,102.0 440.0,102.0 440.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-44b1d482089841e0908ec5fb5eba9b1e-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,304.0 L62,292.0 78,292.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-44b1d482089841e0908ec5fb5eba9b1e-0-1" stroke-width="2px" d="M170,302.0 C170,252.0 225.0,252.0 225.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-44b1d482089841e0908ec5fb5eba9b1e-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M170,304.0 L162,292.0 178,292.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-44b1d482089841e0908ec5fb5eba9b1e-0-2" stroke-width="2px" d="M70,302.0 C70,202.0 230.0,202.0 230.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-44b1d482089841e0908ec5fb5eba9b1e-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M230.0,304.0 L238.0,292.0 222.0,292.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-44b1d482089841e0908ec5fb5eba9b1e-0-3" stroke-width="2px" d="M370,302.0 C370,252.0 425.0,252.0 425.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-44b1d482089841e0908ec5fb5eba9b1e-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M370,304.0 L362,292.0 378,292.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-44b1d482089841e0908ec5fb5eba9b1e-0-4" stroke-width="2px" d="M470,302.0 C470,252.0 525.0,252.0 525.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-44b1d482089841e0908ec5fb5eba9b1e-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">xcomp</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M525.0,304.0 L533.0,292.0 517.0,292.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-44b1d482089841e0908ec5fb5eba9b1e-0-5" stroke-width="2px" d="M670,302.0 C670,152.0 935.0,152.0 935.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-44b1d482089841e0908ec5fb5eba9b1e-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M670,304.0 L662,292.0 678,292.0" fill="currentColor"/>
# </g>
# Sentence:
# -------------------------------------------------------------------------------------------------------
# Given the $13.33 average price target, shares could climb 60% higher in the next year.
#
# Sentence Dependency:
# -------------------------------------------------------------------------------------------------------
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="75bbb158a05e42ad80cf76bdc50a2318-0" class="displacy" width="1650" height="437.0" direction="ltr" style="max-width: none; height: 437.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Given</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="150">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="150">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="250">$</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="250">SYM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">13.33</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="450">average</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="450">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="550">price</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="550">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">target,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">shares</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="850">could</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="850">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">climb</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1050">60%</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1050">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1150">higher</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1150">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1350">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1350">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">next</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1550">year.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1550">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-75bbb158a05e42ad80cf76bdc50a2318-0-0" stroke-width="2px" d="M70,302.0 C70,2.0 950.0,2.0 950.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-75bbb158a05e42ad80cf76bdc50a2318-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,304.0 L62,292.0 78,292.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-75bbb158a05e42ad80cf76bdc50a2318-0-1" stroke-width="2px" d="M170,302.0 C170,102.0 640.0,102.0 640.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-75bbb158a05e42ad80cf76bdc50a2318-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M170,304.0 L162,292.0 178,292.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-75bbb158a05e42ad80cf76bdc50a2318-0-2" stroke-width="2px" d="M270,302.0 C270,252.0 325.0,252.0 325.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-75bbb158a05e42ad80cf76bdc50a2318-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M270,304.0 L262,292.0 278,292.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-75bbb158a05e42ad80cf76bdc50a2318-0-3" stroke-width="2px" d="M370,302.0 C370,152.0 635.0,152.0 635.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-75bbb158a05e42ad80cf76bdc50a2318-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nummod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M370,304.0 L362,292.0 378,292.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-75bbb158a05e42ad80cf76bdc50a2318-0-4" stroke-width="2px" d="M470,302.0 C470,202.0 630.0,202.0 630.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-75bbb158a05e42ad80cf76bdc50a2318-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M470,304.0 L462,292.0 478,292.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-75bbb158a05e42ad80cf76bdc50a2318-0-5" stroke-width="2px" d="M570,302.0 C570,252.0 625.0,252.0 625.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-75bbb158a05e42ad80cf76bdc50a2318-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M570,304.0 L562,292.0 578,292.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-75bbb158a05e42ad80cf76bdc50a2318-0-6" stroke-width="2px" d="M70,302.0 C70,52.0 645.0,52.0 645.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.
# Sentence:
# -------------------------------------------------------------------------------------------------------
# All of this prompted Furlong to keep a Buy rating and $62 price target on the stock.
#
# Sentence Dependency:
# -------------------------------------------------------------------------------------------------------
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="146cd9ef10a847f0993435e133fa192a-0" class="displacy" width="1850" height="387.0" direction="ltr" style="max-width: none; height: 387.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="297.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">All</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="297.0">
#     <tspan class="displacy-word" fill="currentColor" x="150">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="150">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="297.0">
#     <tspan class="displacy-word" fill="currentColor" x="250">this</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="250">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="297.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">prompted</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="297.0">
#     <tspan class="displacy-word" fill="currentColor" x="450">Furlong</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="450">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="297.0">
#     <tspan class="displacy-word" fill="currentColor" x="550">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="550">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="297.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">keep</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="297.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="297.0">
#     <tspan class="displacy-word" fill="currentColor" x="850">Buy</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="850">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="297.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">rating</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="297.0">
#     <tspan class="displacy-word" fill="currentColor" x="1050">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1050">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="297.0">
#     <tspan class="displacy-word" fill="currentColor" x="1150">$</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1150">SYM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="297.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">62</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="297.0">
#     <tspan class="displacy-word" fill="currentColor" x="1350">price</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1350">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="297.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">target</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="297.0">
#     <tspan class="displacy-word" fill="currentColor" x="1550">on</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1550">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="297.0">
#     <tspan class="displacy-word" fill="currentColor" x="1650">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1650">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="297.0">
#     <tspan class="displacy-word" fill="currentColor" x="1750">stock.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1750">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-146cd9ef10a847f0993435e133fa192a-0-0" stroke-width="2px" d="M70,252.0 C70,102.0 340.0,102.0 340.0,252.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-146cd9ef10a847f0993435e133fa192a-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,254.0 L62,242.0 78,242.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-146cd9ef10a847f0993435e133fa192a-0-1" stroke-width="2px" d="M70,252.0 C70,202.0 130.0,202.0 130.0,252.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-146cd9ef10a847f0993435e133fa192a-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M130.0,254.0 L138.0,242.0 122.0,242.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-146cd9ef10a847f0993435e133fa192a-0-2" stroke-width="2px" d="M170,252.0 C170,202.0 230.0,202.0 230.0,252.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-146cd9ef10a847f0993435e133fa192a-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M230.0,254.0 L238.0,242.0 222.0,242.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-146cd9ef10a847f0993435e133fa192a-0-3" stroke-width="2px" d="M370,252.0 C370,202.0 430.0,202.0 430.0,252.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-146cd9ef10a847f0993435e133fa192a-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M430.0,254.0 L438.0,242.0 422.0,242.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-146cd9ef10a847f0993435e133fa192a-0-4" stroke-width="2px" d="M570,252.0 C570,202.0 630.0,202.0 630.0,252.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-146cd9ef10a847f0993435e133fa192a-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">aux</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M570,254.0 L562,242.0 578,242.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-146cd9ef10a847f0993435e133fa192a-0-5" stroke-width="2px" d="M370,252.0 C370,102.0 640.0,102.0 640.0,252.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-146cd9e
# Sentence:
# -------------------------------------------------------------------------------------------------------
# The $62.33 average price target brings the upside potential to 91%.
#
# Sentence Dependency:
# -------------------------------------------------------------------------------------------------------
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="cc0312fb584f4334b79202554a1a4a8f-0" class="displacy" width="1250" height="387.0" direction="ltr" style="max-width: none; height: 387.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="297.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">The</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="297.0">
#     <tspan class="displacy-word" fill="currentColor" x="150">$</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="150">SYM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="297.0">
#     <tspan class="displacy-word" fill="currentColor" x="250">62.33</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="250">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="297.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">average</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="297.0">
#     <tspan class="displacy-word" fill="currentColor" x="450">price</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="450">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="297.0">
#     <tspan class="displacy-word" fill="currentColor" x="550">target</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="550">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="297.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">brings</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="297.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="297.0">
#     <tspan class="displacy-word" fill="currentColor" x="850">upside</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="850">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="297.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">potential</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="297.0">
#     <tspan class="displacy-word" fill="currentColor" x="1050">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1050">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="297.0">
#     <tspan class="displacy-word" fill="currentColor" x="1150">91%.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1150">NUM</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-cc0312fb584f4334b79202554a1a4a8f-0-0" stroke-width="2px" d="M70,252.0 C70,2.0 550.0,2.0 550.0,252.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-cc0312fb584f4334b79202554a1a4a8f-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,254.0 L62,242.0 78,242.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-cc0312fb584f4334b79202554a1a4a8f-0-1" stroke-width="2px" d="M170,252.0 C170,202.0 230.0,202.0 230.0,252.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-cc0312fb584f4334b79202554a1a4a8f-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M170,254.0 L162,242.0 178,242.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-cc0312fb584f4334b79202554a1a4a8f-0-2" stroke-width="2px" d="M270,252.0 C270,102.0 540.0,102.0 540.0,252.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-cc0312fb584f4334b79202554a1a4a8f-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nummod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M270,254.0 L262,242.0 278,242.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-cc0312fb584f4334b79202554a1a4a8f-0-3" stroke-width="2px" d="M370,252.0 C370,152.0 535.0,152.0 535.0,252.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-cc0312fb584f4334b79202554a1a4a8f-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M370,254.0 L362,242.0 378,242.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-cc0312fb584f4334b79202554a1a4a8f-0-4" stroke-width="2px" d="M470,252.0 C470,202.0 530.0,202.0 530.0,252.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-cc0312fb584f4334b79202554a1a4a8f-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M470,254.0 L462,242.0 478,242.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-cc0312fb584f4334b79202554a1a4a8f-0-5" stroke-width="2px" d="M570,252.0 C570,202.0 630.0,202.0 630.0,252.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-cc0312fb584f4334b79202554a1a4a8f-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M570,254.0 L562,242.0 578,242.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-cc0312fb584f4334b79202554a1a4a8f-0-6" stroke-width="2px" d="M770,252.0 C770,152.0 935.0,152.0 935.0,252.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-cc0312fb584f4334b79202554a1a4a8f-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M770,254.0 L762,242.0 778,242.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-cc0312fb584f4334b79202554a1a4a8f-0-7" stroke-width="2px" d="M870,252.0 C870,202.0 930.0,202.0 930.0,252.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-cc0312fb584f4334b79202554a1a4a8f-0-7" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M870,254.0 L862,242.0 878,242.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-cc0312fb584f433
# Sentence:
# -------------------------------------------------------------------------------------------------------
# Along with the call, he attached a $67 price target, suggesting 68% upside potential from current levels.
#
# Sentence Dependency:
# -------------------------------------------------------------------------------------------------------
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="caab1842f930478ea4b11f5ba9e08507-0" class="displacy" width="1850" height="437.0" direction="ltr" style="max-width: none; height: 437.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Along</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="150">with</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="150">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="250">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="250">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">call,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="450">he</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="450">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="550">attached</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="550">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">$</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">SYM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="850">67</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="850">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">price</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1050">target,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1050">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1150">suggesting</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1150">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">68%</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1350">upside</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1350">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">potential</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1550">from</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1550">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1650">current</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1650">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1750">levels.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1750">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-caab1842f930478ea4b11f5ba9e08507-0-0" stroke-width="2px" d="M70,302.0 C70,52.0 545.0,52.0 545.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-caab1842f930478ea4b11f5ba9e08507-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,304.0 L62,292.0 78,292.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-caab1842f930478ea4b11f5ba9e08507-0-1" stroke-width="2px" d="M70,302.0 C70,252.0 125.0,252.0 125.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-caab1842f930478ea4b11f5ba9e08507-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M125.0,304.0 L133.0,292.0 117.0,292.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-caab1842f930478ea4b11f5ba9e08507-0-2" stroke-width="2px" d="M270,302.0 C270,252.0 325.0,252.0 325.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-caab1842f930478ea4b11f5ba9e08507-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M270,304.0 L262,292.0 278,292.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-caab1842f930478ea4b11f5ba9e08507-0-3" stroke-width="2px" d="M170,302.0 C170,202.0 330.0,202.0 330.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-caab1842f930478ea4b11f5ba9e08507-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M330.0,304.0 L338.0,292.0 322.0,292.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-caab1842f930478ea4b11f5ba9e08507-0-4" stroke-width="2px" d="M470,302.0 C470,252.0 525.0,252.0 525.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-caab1842f930478ea4b11f5ba9e08507-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M470,304.0 L462,292.0 478,292.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-caab1842f930478ea4b11f5ba9e08507-0-5" stroke-width="2px" d="M670,302.0 C670,102.0 1040.0,102.0 1040.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arr
# Sentence:
# -------------------------------------------------------------------------------------------------------
# In addition, the $69.89 average price target indicates 75% upside potential.
#
# Sentence Dependency:
# -------------------------------------------------------------------------------------------------------
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="b288f9e40d5e4c19ada3f804a39ee69a-0" class="displacy" width="1250" height="387.0" direction="ltr" style="max-width: none; height: 387.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="297.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">In</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="297.0">
#     <tspan class="displacy-word" fill="currentColor" x="150">addition,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="150">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="297.0">
#     <tspan class="displacy-word" fill="currentColor" x="250">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="250">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="297.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">$</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">SYM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="297.0">
#     <tspan class="displacy-word" fill="currentColor" x="450">69.89</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="450">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="297.0">
#     <tspan class="displacy-word" fill="currentColor" x="550">average</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="550">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="297.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">price</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="297.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">target</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="297.0">
#     <tspan class="displacy-word" fill="currentColor" x="850">indicates</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="850">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="297.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">75%</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="297.0">
#     <tspan class="displacy-word" fill="currentColor" x="1050">upside</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1050">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="297.0">
#     <tspan class="displacy-word" fill="currentColor" x="1150">potential.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1150">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b288f9e40d5e4c19ada3f804a39ee69a-0-0" stroke-width="2px" d="M70,252.0 C70,2.0 850.0,2.0 850.0,252.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b288f9e40d5e4c19ada3f804a39ee69a-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,254.0 L62,242.0 78,242.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b288f9e40d5e4c19ada3f804a39ee69a-0-1" stroke-width="2px" d="M70,252.0 C70,202.0 130.0,202.0 130.0,252.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b288f9e40d5e4c19ada3f804a39ee69a-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M130.0,254.0 L138.0,242.0 122.0,242.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b288f9e40d5e4c19ada3f804a39ee69a-0-2" stroke-width="2px" d="M270,252.0 C270,52.0 745.0,52.0 745.0,252.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b288f9e40d5e4c19ada3f804a39ee69a-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M270,254.0 L262,242.0 278,242.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b288f9e40d5e4c19ada3f804a39ee69a-0-3" stroke-width="2px" d="M370,252.0 C370,202.0 430.0,202.0 430.0,252.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b288f9e40d5e4c19ada3f804a39ee69a-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M370,254.0 L362,242.0 378,242.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b288f9e40d5e4c19ada3f804a39ee69a-0-4" stroke-width="2px" d="M470,252.0 C470,102.0 740.0,102.0 740.0,252.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b288f9e40d5e4c19ada3f804a39ee69a-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nummod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M470,254.0 L462,242.0 478,242.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b288f9e40d5e4c19ada3f804a39ee69a-0-5" stroke-width="2px" d="M570,252.0 C570,152.0 735.0,152.0 735.0,252.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b288f9e40d5e4c19ada3f804a39ee69a-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M570,254.0 L562,242.0 578,242.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b288f9e40d5e4c19ada3f804a39ee69a-0-6" stroke-width="2px" d="M670,252.0 C670,202.0 730.0,202.0 730.0,252.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b288f9e40d5e4c19ada3f804a39ee69a-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M670,254.0 L662,242.0 678,242.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b288f9e40d5e4c19ada3f804a39ee69a-0-7" stroke-width="2px" d="M770,252.0 C770,202.0 830.0,202.0 830.0,252.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b288f9e40d5e4c19ada3f804a39ee69a-0-7" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M770,254.0 L762,242.0 778,242.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b2

# %% [markdown]
# # 2. Relation Extraction
#
# Identify relation between entities (Affiliation, Location, Part of, Social). Identify if entity is object or subject (Subject does the action. Object is the center of action.)

# %% [markdown]
# ### 2.1. Displaying relation extraction

# %%
relation_entities(new_content)
# Out:
# Entity:      Bloomberg
# Relation:    Companies, agencies, institutions, etc.
# Dependency:  None
# POS:         proper noun
# -------------------------------------------------------------------------------------------------------
#
# Entity:      Amazon.com Inc.
# Relation:    Companies, agencies, institutions, etc.
# Dependency:  compound
# POS:         proper noun
# -------------------------------------------------------------------------------------------------------
#
# Entity:      Echelon Fitness
# Relation:    Companies, agencies, institutions, etc.
# Dependency:  compound
# POS:         proper noun
# -------------------------------------------------------------------------------------------------------
#
# Entity:      Echelon
# Relation:    Companies, agencies, institutions, etc.
# Dependency:  nominal subject
# POS:         proper noun
# -------------------------------------------------------------------------------------------------------
#
# Entity:      EX
# Relation:    Companies, agencies, institutions, etc.
# Dependency:  compound
# POS:         proper noun
# -------------------------------------------------------------------------------------------------------
#
# Entity:      earlier this week
# Relation:    Absolute or relative dates or periods
# Dependency:  adverbial modifier
# POS:         adverb
# -------------------------------------------------------------------------------------------------------
#
# Entity:      Amazon
# Relation:    Companies, agencies, institutions, etc.
# Dependency:  object of preposition
# POS:         proper noun
# -------------------------------------------------------------------------------------------------------
#
# Entity:      500
# Relation:    Monetary values, including unit
# Dependency:  object of preposition
# POS:         numeral
# -------------------------------------------------------------------------------------------------------
#
# Entity:      Peloton Interactive Inc.
# Relation:    Companies, agencies, institutions, etc.
# Dependency:  compound
# POS:         proper noun
# -------------------------------------------------------------------------------------------------------
#
# Entity:      late Tuesday
# Relation:    Absolute or relative dates or periods
# Dependency:  adjectival modifier
# POS:         adjective
# -------------------------------------------------------------------------------------------------------
#
# Entity:      annual
# Relation:    Absolute or relative dates or periods
# Dependency:  adjectival modifier
# POS:         adjective
# -------------------------------------------------------------------------------------------------------
#
# Entity:      as much as 6.7%
# Relation:    Percentage, including "%"
# Dependency:  adverbial modifier
# POS:         adverb
# -------------------------------------------------------------------------------------------------------
#
# Entity:      early Tuesday
# Relation:    Absolute or relative dates or periods
# Dependency:  adjectival modifier
# POS:         adjective
# -------------------------------------------------------------------------------------------------------
#
# Entity:      less than 1%
# Relation:    Percentage, including "%"
# Dependency:  adjectival modifier
# POS:         adjective
# -------------------------------------------------------------------------------------------------------
#
# Entity:      New York
# Relation:    Countries, cities, states
# Dependency:  compound
# POS:         proper noun
# -------------------------------------------------------------------------------------------------------
#
# Entity:      Walmart.com
# Relation:    Companies, agencies, institutions, etc.
# Dependency:  object of preposition
# POS:         proper noun
# -------------------------------------------------------------------------------------------------------
#
# Entity:      March
# Relation:    Absolute or relative dates or periods
# Dependency:  object of preposition
# POS:         proper noun
# -------------------------------------------------------------------------------------------------------
#
# Entity:      Peloton
# Relation:    People, including fictional
# Dependency:  possession modifier
# POS:         proper noun
# -------------------------------------------------------------------------------------------------------
#
# Entity:      KeyBanc Capital Markets
# Relation:    Companies, agencies, institutions, etc.
# Dependency:  compound
# POS:         proper noun
# -------------------------------------------------------------------------------------------------------
#
# Entity:      Edward Yruma
# Relation:    People, including fictional
# Dependency:  compound
# POS:         proper noun
# -------------------------------------------------------------------------------------------------------
#
# Entity:      Updates
# Relation:    Companies, agencies, institutions, etc.
# Dependency:  None
# POS:         noun
# -------------------------------------------------------------------------------------------------------
#
# Entity:      fifth
# Relation:    "first", "second", etc.
# Dependency:  adjectival modifier
# POS:         adjective
# -------------------------------------------------------------------------------------------------------
#
# Entity:      Bloomberg L.P.
# Relation:    Companies, agencies, institutions, etc.
# Dependency:  compound
# POS:         proper noun
# -------------------------------------------------------------------------------------------------------
#
# Entity:      One
# Relation:    Numerals that do not fall under another type
# Dependency:  nominal subject
# POS:         numeral
# -------------------------------------------------------------------------------------------------------
#
# Entity:      the last few weeks
# Relation:    Absolute or relative dates or periods
# Dependency:  determiner
# POS:         determiner
# -------------------------------------------------------------------------------------------------------
#
# Entity:      three
# Relation:    Numerals that do not fall under another type
# Dependency:  numeric modifier
# POS:         numeral
# -------------------------------------------------------------------------------------------------------
#
# Entity:      52-week
# Relation:    Absolute or relative dates or periods
# Dependency:  adjectival modifier
# POS:         numeral
# -------------------------------------------------------------------------------------------------------
#
# Entity:      Progenity
# Relation:    Companies, agencies, institutions, etc.
# Dependency:  None
# POS:         proper noun
# -------------------------------------------------------------------------------------------------------
#
# Entity:      Nasdaq
# Relation:    Companies, agencies, institutions, etc.
# Dependency:  object of preposition
# POS:         proper noun
# -------------------------------------------------------------------------------------------------------
#
# Entity:      June
# Relation:    Absolute or relative dates or periods
# Dependency:  object of preposition
# POS:         proper noun
# -------------------------------------------------------------------------------------------------------
#
# Entity:      44%
# Relation:    Percentage, including "%"
# Dependency:  numeric modifier
# POS:         numeral
# -------------------------------------------------------------------------------------------------------
#
# Entity:      8.11
# Relation:    Monetary values, including unit
# Dependency:  object of preposition
# POS:         numeral
# -------------------------------------------------------------------------------------------------------
#
# Entity:      Piper Sandler
# Relation:    People, including fictional
# Dependency:  compound
# POS:         proper noun
# -------------------------------------------------------------------------------------------------------
#
# Entity:      Steven Mah
# Relation:    People, including fictional
# Dependency:  compound
# POS:         proper noun
# -------------------------------------------------------------------------------------------------------
#
# Entity:      Q2 2020
# Relation:    Absolute or relative dates or periods
# Dependency:  modifier of nominal
# POS:         proper noun
# -------------------------------------------------------------------------------------------------------
#
# Entity:      late Q2 2020
# Relation:    Absolute or relative dates or periods
# Dependency:  adjectival modifier
# POS:         adjective
# -------------------------------------------------------------------------------------------------------
#
# Entity:      75,000
# Relation:    Numerals that do not fall under another type
# Dependency:  numeric modifier
# POS:         numeral
# -------------------------------------------------------------------------------------------------------
#
# Entity:      Q1 2020
# Relation:    Absolute or relative dates or periods
# Dependency:  object of preposition
# POS:         proper noun
# -------------------------------------------------------------------------------------------------------
#
# Entity:      Mah
# Relation:    People, including fictional
# Dependency:  nominal subject
# POS:         proper noun
# -------------------------------------------------------------------------------------------------------
#
# Entity:      monthly
# Relation:    Absolute or relative dates or periods
# Dependency:  adjectival modifier
# POS:         adjective
# -------------------------------------------------------------------------------------------------------
#
# Entity:      COVID
# Relation:    Companies, agencies, institutions, etc.
# Dependency:  adjectival modifier
# POS:         adjective
# -------------------------------------------------------------------------------------------------------
#
# Entity:      Aetna
# Relation:    Companies, agencies, institutions, etc.
# Dependency:  nominal subject
# POS:         proper noun
# -------------------------------------------------------------------------------------------------------
#
# Entity:      year-end
# Relation:    Absolute or relative dates or periods
# Dependency:  compound
# POS:         noun
# -------------------------------------------------------------------------------------------------------
#
# Entity:      the American College of Obstetricians
# Relation:    Companies, agencies, institutions, etc.
# Dependency:  determiner
# POS:         determiner
# -------------------------------------------------------------------------------------------------------
#
# Entity:      Gynecologists
# Relation:    Companies, agencies, institutions, etc.
# Dependency:  conjunct
# POS:         proper noun
# -------------------------------------------------------------------------------------------------------
#
# Entity:      ACOG
# Relation:    Companies, agencies, institutions, etc.
# Dependency:  appositional modifier
# POS:         proper noun
# -------------------------------------------------------------------------------------------------------
#
# Entity:      fourth
# Relation:    "first", "second", etc.
# Dependency:  adjectival modifier
# POS:         adjective
# -------------------------------------------------------------------------------------------------------
#
# Entity:      2021
# Relation:    Absolute or relative dates or periods
# Dependency:  object of preposition
# POS:         numeral
# -------------------------------------------------------------------------------------------------------
#
# Entity:      RNA
# Relation:    Objects, vehicles, foods, etc. (not services)
# Dependency:  conjunct
# POS:         proper noun
# -------------------------------------------------------------------------------------------------------
#
# Entity:      Q4 2020
# Relation:    Absolute or relative dates or periods
# Dependency:  object of preposition
# POS:         proper noun
# -------------------------------------------------------------------------------------------------------
#
# Entity:      ~2.3 billion
# Relation:    Monetary values, including unit
# Dependency:  compound
# POS:         numeral
# -------------------------------------------------------------------------------------------------------
#
# Entity:      PROG
# Relation:    Companies, agencies, institutions, etc.
# Dependency:  nominal subject
# POS:         proper noun
# -------------------------------------------------------------------------------------------------------
#
# Entity:      first GI Precision Medicine
# Relation:    Companies, agencies, institutions, etc.
# Dependency:  adjectival modifier
# POS:         adjective
# -------------------------------------------------------------------------------------------------------
#
# Entity:      Pharma
# Relation:    Companies, agencies, institutions, etc.
# Dependency:  compound
# POS:         proper noun
# -------------------------------------------------------------------------------------------------------
#
# Entity:      August
# Relation:    Absolute or relative dates or periods
# Dependency:  object of preposition
# POS:         proper noun
# -------------------------------------------------------------------------------------------------------
#
# Entity:      The Oral Biotherapeutic Delivery System
# Relation:    Companies, agencies, institutions, etc.
# Dependency:  determiner
# POS:         determiner
# -------------------------------------------------------------------------------------------------------
#
# Entity:      17
# Relation:    Monetary values, including unit
# Dependency:  numeric modifier
# POS:         numeral
# -------------------------------------------------------------------------------------------------------
#
# Entity:      twelve-month
# Relation:    Absolute or relative dates or periods
# Dependency:  numeric modifier
# POS:         numeral
# -------------------------------------------------------------------------------------------------------
#
# Entity:      105%
# Relation:    Percentage, including "%"
# Dependency:  numeric modifier
# POS:         numeral
# -------------------------------------------------------------------------------------------------------
#
# Entity:      4
# Relation:    Numerals that do not fall under another type
# Dependency:  appositional modifier
# POS:         numeral
# -------------------------------------------------------------------------------------------------------
#
# Entity:      the last three months
# Relation:    Absolute or relative dates or periods
# Dependency:  determiner
# POS:         determiner
# -------------------------------------------------------------------------------------------------------
#
# Entity:      13.33
# Relation:    Monetary values, including unit
# Dependency:  numeric modifier
# POS:         numeral
# -------------------------------------------------------------------------------------------------------
#
# Entity:      60%
# Relation:    Percentage, including "%"
# Dependency:  numeric modifier
# POS:         numeral
# -------------------------------------------------------------------------------------------------------
#
# Entity:      the next year
# Relation:    Absolute or relative dates or periods
# Dependency:  determiner
# POS:         determiner
# -------------------------------------------------------------------------------------------------------
#
# Entity:      Tactile Systems Technology
# Relation:    Companies, agencies, institutions, etc.
# Dependency:  compound
# POS:         proper noun
# -------------------------------------------------------------------------------------------------------
#
# Entity:      TCMD
# Relation:    Companies, agencies, institutions, etc.
# Dependency:  appositional modifier
# POS:         proper noun
# -------------------------------------------------------------------------------------------------------
#
# Entity:      52%
# Relation:    Percentage, including "%"
# Dependency:  numeric modifier
# POS:         numeral
# -------------------------------------------------------------------------------------------------------
#
# Entity:      32.67
# Relation:    Monetary values, including unit
# Dependency:  numeric modifier
# POS:         numeral
# -------------------------------------------------------------------------------------------------------
#
# Entity:      29.47
# Relation:    Monetary values, including unit
# Dependency:  numeric modifier
# POS:         numeral
# -------------------------------------------------------------------------------------------------------
#
# Entity:      Canaccord
# Relation:    Companies, agencies, institutions, etc.
# Dependency:  object of preposition
# POS:         proper noun
# -------------------------------------------------------------------------------------------------------
#
# Entity:      Cecilia Furlong
# Relation:    People, including fictional
# Dependency:  compound
# POS:         proper noun
# -------------------------------------------------------------------------------------------------------
#
# Entity:      the second half of March
# Relation:    Absolute or relative dates or periods
# Dependency:  determiner
# POS:         determiner
# -------------------------------------------------------------------------------------------------------
#
# Entity:      50%
# Relation:    Percentage, including "%"
# Dependency:  numeric modifier
# POS:         numeral
# -------------------------------------------------------------------------------------------------------
#
# Entity:      the first half of the month
# Relation:    Absolute or relative dates or periods
# Dependency:  determiner
# POS:         determiner
# -------------------------------------------------------------------------------------------------------
#
# Entity:      April
# Relation:    Absolute or relative dates or periods
# Dependency:  object of preposition
# POS:         proper noun
# -------------------------------------------------------------------------------------------------------
#
# Entity:      May
# Relation:    Absolute or relative dates or periods
# Dependency:  auxiliary
# POS:         proper noun
# -------------------------------------------------------------------------------------------------------
#
# Entity:      the end of May.
# Relation:    Absolute or relative dates or periods
# Dependency:  determiner
# POS:         determiner
# -------------------------------------------------------------------------------------------------------
#
# Entity:      Furlong
# Relation:    People, including fictional
# Dependency:  nominal subject
# POS:         proper noun
# -------------------------------------------------------------------------------------------------------
#
# Entity:      Flexitouch
# Relation:    People, including fictional
# Dependency:  direct object
# POS:         proper noun
# -------------------------------------------------------------------------------------------------------
#
# Entity:      Dan Reuvers
# Relation:    People, including fictional
# Dependency:  compound
# POS:         proper noun
# -------------------------------------------------------------------------------------------------------
#
# Entity:      Airwear
# Relation:    Objects, vehicles, foods, etc. (not services)
# Dependency:  compound
# POS:         proper noun
# -------------------------------------------------------------------------------------------------------
#
# Entity:      Entre
# Relation:    Objects, vehicles, foods, etc. (not services)
# Dependency:  conjunct
# POS:         proper noun
# -------------------------------------------------------------------------------------------------------
#
# Entity:      today
# Relation:    Absolute or relative dates or periods
# Dependency:  noun phrase as adverbial modifier
# POS:         noun
# -------------------------------------------------------------------------------------------------------
#
# Entity:      Head & Neck
# Relation:    Companies, agencies, institutions, etc.
# Dependency:  modifier of nominal
# POS:         proper noun
# -------------------------------------------------------------------------------------------------------
#
# Entity:      62
# Relation:    Monetary values, including unit
# Dependency:  numeric modifier
# POS:         numeral
# -------------------------------------------------------------------------------------------------------
#
# Entity:      90%
# Relation:    Percentage, including "%"
# Dependency:  numeric modifier
# POS:         numeral
# -------------------------------------------------------------------------------------------------------
#
# Entity:      3
# Relation:    Numerals that do not fall under another type
# Dependency:  numeric modifier
# POS:         numeral
# -------------------------------------------------------------------------------------------------------
#
# Entity:      1 Hold
# Relation:    Titles of books, songs, etc.
# Dependency:  numeric modifier
# POS:         numeral
# -------------------------------------------------------------------------------------------------------
#
# Entity:      62.33
# Relation:    Monetary values, including unit
# Dependency:  numeric modifier
# POS:         numeral
# -------------------------------------------------------------------------------------------------------
#
# Entity:      91%
# Relation:    Percentage, including "%"
# Dependency:  numeric modifier
# POS:         numeral
# -------------------------------------------------------------------------------------------------------
#
# Entity:      uniQure N.V.
# Relation:    Companies, agencies, institutions, etc.
# Dependency:  None
# POS:         adjective
# -------------------------------------------------------------------------------------------------------
#
# Entity:      QURE
# Relation:    Companies, agencies, institutions, etc.
# Dependency:  noun phrase as adverbial modifier
# POS:         proper noun
# -------------------------------------------------------------------------------------------------------
#
# Entity:      40
# Relation:    Monetary values, including unit
# Dependency:  object of preposition
# POS:         numeral
# -------------------------------------------------------------------------------------------------------
#
# Entity:      36.20
# Relation:    Monetary values, including unit
# Dependency:  object of preposition
# POS:         numeral
# -------------------------------------------------------------------------------------------------------
#
# Entity:      SVB Leerink
# Relation:    Companies, agencies, institutions, etc.
# Dependency:  compound
# POS:         proper noun
# -------------------------------------------------------------------------------------------------------
#
# Entity:      Joseph Schwartz
# Relation:    People, including fictional
# Dependency:  compound
# POS:         proper noun
# -------------------------------------------------------------------------------------------------------
#
# Entity:      CSL Behring
# Relation:    Companies, agencies, institutions, etc.
# Dependency:  compound
# POS:         proper noun
# -------------------------------------------------------------------------------------------------------
#
# Entity:      Huntington
# Relation:    Countries, cities, states
# Dependency:  object of preposition
# POS:         proper noun
# -------------------------------------------------------------------------------------------------------
#
# Entity:      Schwartz
# Relation:    People, including fictional
# Dependency:  nominal subject
# POS:         proper noun
# -------------------------------------------------------------------------------------------------------
#
# Entity:      CNS
# Relation:    Companies, agencies, institutions, etc.
# Dependency:  compound
# POS:         proper noun
# -------------------------------------------------------------------------------------------------------
#
# Entity:      Phase 3
# Relation:    Named hurricanes, battles, wars, sports events, etc.
# Dependency:  modifier of nominal
# POS:         proper noun
# -------------------------------------------------------------------------------------------------------
#
# Entity:      26-week
# Relation:    Absolute or relative dates or periods
# Dependency:  adjectival modifier
# POS:         adjective
# -------------------------------------------------------------------------------------------------------
#
# Entity:      54
# Relation:    Numerals that do not fall under another type
# Dependency:  numeric modifier
# POS:         numeral
# -------------------------------------------------------------------------------------------------------
#
# Entity:      YE20
# Relation:    Numerals that do not fall under another type
# Dependency:  object of preposition
# POS:         proper noun
# -------------------------------------------------------------------------------------------------------
#
# Entity:      2b
# Relation:    Numerals that do not fall under another type
# Dependency:  numeric modifier
# POS:         numeral
# -------------------------------------------------------------------------------------------------------
#
# Entity:      41%
# Relation:    Percentage, including "%"
# Dependency:  numeric modifier
# POS:         numeral
# -------------------------------------------------------------------------------------------------------
#
# Entity:      one year
# Relation:    Absolute or relative dates or periods
# Dependency:  numeric modifier
# POS:         numeral
# -------------------------------------------------------------------------------------------------------
#
# Entity:      U.S.
# Relation:    Countries, cities, states
# Dependency:  object of preposition
# POS:         proper noun
# -------------------------------------------------------------------------------------------------------
#
# Entity:      EU
# Relation:    Companies, agencies, institutions, etc.
# Dependency:  conjunct
# POS:         proper noun
# -------------------------------------------------------------------------------------------------------
#
# Entity:      more than $2 billion
# Relation:    Monetary values, including unit
# Dependency:  adjectival modifier
# POS:         adjective
# -------------------------------------------------------------------------------------------------------
#
# Entity:      $450 million
# Relation:    Monetary values, including unit
# Dependency:  modifier of quantifier
# POS:         symbol
# -------------------------------------------------------------------------------------------------------
#
# Entity:      $1.6 billion
# Relation:    Monetary values, including unit
# Dependency:  modifier of quantifier
# POS:         symbol
# -------------------------------------------------------------------------------------------------------
#
# Entity:      AAV
# Relation:    Companies, agencies, institutions, etc.
# Dependency:  compound
# POS:         proper noun
# -------------------------------------------------------------------------------------------------------
#
# Entity:      67
# Relation:    Monetary values, including unit
# Dependency:  numeric modifier
# POS:         numeral
# -------------------------------------------------------------------------------------------------------
#
# Entity:      68%
# Relation:    Percentage, including "%"
# Dependency:  numeric modifier
# POS:         numeral
# -------------------------------------------------------------------------------------------------------
#
# Entity:      9
# Relation:    Numerals that do not fall under another type
# Dependency:  numeric modifier
# POS:         numeral
# -------------------------------------------------------------------------------------------------------
#
# Entity:      69.89
# Relation:    Monetary values, including unit
# Dependency:  numeric modifier
# POS:         numeral
# -------------------------------------------------------------------------------------------------------
#
# Entity:      75%
# Relation:    Percentage, including "%"
# Dependency:  numeric modifier
# POS:         numeral
# -------------------------------------------------------------------------------------------------------
# Entity:      Tesla Inc.’s
# Relation:    Companies, agencies, institutions, etc.
# Dependency:  compound
# POS:         proper noun
# -------------------------------------------------------------------------------------------------------
#
# Entity:      Battery Day
# Relation:    Titles of books, songs, etc.
# Dependency:  compound
# POS:         proper noun
# -------------------------------------------------------------------------------------------------------
#
# Entity:      $320 billion
# Relation:    Monetary values, including unit
# Dependency:  modifier of quantifier
# POS:         symbol
# -------------------------------------------------------------------------------------------------------
#
# Entity:      this year
# Relation:    Absolute or relative dates or periods
# Dependency:  determiner
# POS:         determiner
# -------------------------------------------------------------------------------------------------------
#
# Entity:      Elon Musk
# Relation:    People, including fictional
# Dependency:  compound
# POS:         proper noun
# -------------------------------------------------------------------------------------------------------
#
# Entity:      Tuesday
# Relation:    Absolute or relative dates or periods
# Dependency:  noun phrase as adverbial modifier
# POS:         proper noun
# -------------------------------------------------------------------------------------------------------
#
# Entity:      25,000
# Relation:    Monetary values, including unit
# Dependency:  numeric modifier
# POS:         numeral
# -------------------------------------------------------------------------------------------------------
#
# Entity:      half
# Relation:    Numerals that do not fall under another type
# Dependency:  object of preposition
# POS:         noun
# -------------------------------------------------------------------------------------------------------
#
# Entity:      the next three years
# Relation:    Absolute or relative dates or periods
# Dependency:  determiner
# POS:         determiner
# -------------------------------------------------------------------------------------------------------
#
# Entity:      Tesla
# Relation:    Companies, agencies, institutions, etc.
# Dependency:  possession modifier
# POS:         proper noun
# -------------------------------------------------------------------------------------------------------
#
# Entity:      Robert W. Baird
# Relation:    People, including fictional
# Dependency:  compound
# POS:         proper noun
# -------------------------------------------------------------------------------------------------------
#
# Entity:      Ben Kallo
# Relation:    People, including fictional
# Dependency:  compound
# POS:         proper noun
# -------------------------------------------------------------------------------------------------------
#
# Entity:      Wednesday
# Relation:    Absolute or relative dates or periods
# Dependency:  compound
# POS:         proper noun
# -------------------------------------------------------------------------------------------------------
#
# Entity:      Patrick Hummel
# Relation:    People, including fictional
# Dependency:  compound
# POS:         proper noun
# -------------------------------------------------------------------------------------------------------
#
# Entity:      UBS
# Relation:    Companies, agencies, institutions, etc.
# Dependency:  object of preposition
# POS:         proper noun
# -------------------------------------------------------------------------------------------------------
#
# Entity:      5.4%
# Relation:    Percentage, including "%"
# Dependency:  numeric modifier
# POS:         numeral
# -------------------------------------------------------------------------------------------------------
#
# Entity:      401.19
# Relation:    Monetary values, including unit
# Dependency:  object of preposition
# POS:         numeral
# -------------------------------------------------------------------------------------------------------
#
# Entity:      9:50 a.m.
# Relation:    Times smaller than a day
# Dependency:  numeric modifier
# POS:         numeral
# -------------------------------------------------------------------------------------------------------
#
# Entity:      about 400%
# Relation:    Percentage, including "%"
# Dependency:  adverbial modifier
# POS:         adverb
# -------------------------------------------------------------------------------------------------------
#
# Entity:      Musk
# Relation:    Companies, agencies, institutions, etc.
# Dependency:  nominal subject
# POS:         proper noun
# -------------------------------------------------------------------------------------------------------
#
# Entity:      49
# Relation:    Absolute or relative dates or periods
# Dependency:  appositional modifier
# POS:         numeral
# -------------------------------------------------------------------------------------------------------
#
# Entity:      20 million
# Relation:    Numerals that do not fall under another type
# Dependency:  compound
# POS:         numeral
# -------------------------------------------------------------------------------------------------------
#
# Entity:      the weeks
# Relation:    Absolute or relative dates or periods
# Dependency:  determiner
# POS:         determiner
# -------------------------------------------------------------------------------------------------------
#
# Entity:      three years
# Relation:    Absolute or relative dates or periods
# Dependency:  numeric modifier
# POS:         numeral
# -------------------------------------------------------------------------------------------------------
#
# Entity:      Gene Munster
# Relation:    People, including fictional
# Dependency:  compound
# POS:         proper noun
# -------------------------------------------------------------------------------------------------------
#
# Entity:      Loup Ventures
# Relation:    Companies, agencies, institutions, etc.
# Dependency:  compound
# POS:         proper noun
# -------------------------------------------------------------------------------------------------------
#
# Entity:      tomorrow
# Relation:    Absolute or relative dates or periods
# Dependency:  noun phrase as adverbial modifier
# POS:         noun
# -------------------------------------------------------------------------------------------------------
#
# Entity:      Fremont
# Relation:    Countries, cities, states
# Dependency:  object of preposition
# POS:         proper noun
# -------------------------------------------------------------------------------------------------------
#
# Entity:      California
# Relation:    Countries, cities, states
# Dependency:  appositional modifier
# POS:         proper noun
# -------------------------------------------------------------------------------------------------------
#
# Entity:      Nevada
# Relation:    Countries, cities, states
# Dependency:  object of preposition
# POS:         proper noun
# -------------------------------------------------------------------------------------------------------
#
# Entity:      2023
# Relation:    Absolute or relative dates or periods
# Dependency:  object of preposition
# POS:         numeral
# -------------------------------------------------------------------------------------------------------
#
# Entity:      about three years from now
# Relation:    Absolute or relative dates or periods
# Dependency:  adverbial modifier
# POS:         adverb
# -------------------------------------------------------------------------------------------------------
#
# Entity:      35,000
# Relation:    Monetary values, including unit
# Dependency:  numeric modifier
# POS:         numeral
# -------------------------------------------------------------------------------------------------------
#
# Entity:      Three years
# Relation:    Absolute or relative dates or periods
# Dependency:  numeric modifier
# POS:         numeral
# -------------------------------------------------------------------------------------------------------
#
# Entity:      early 2016
# Relation:    Absolute or relative dates or periods
# Dependency:  adjectival modifier
# POS:         adjective
# -------------------------------------------------------------------------------------------------------
#
# Entity:      10 days later
# Relation:    Absolute or relative dates or periods
# Dependency:  numeric modifier
# POS:         numeral
# -------------------------------------------------------------------------------------------------------
#
# Entity:      Model 3
# Relation:    Objects, vehicles, foods, etc. (not services)
# Dependency:  nominal subject
# POS:         proper noun
# -------------------------------------------------------------------------------------------------------
#
# Entity:      37,990
# Relation:    Monetary values, including unit
# Dependency:  attribute
# POS:         numeral
# -------------------------------------------------------------------------------------------------------
#
# Entity:      Today
# Relation:    Absolute or relative dates or periods
# Dependency:  possession modifier
# POS:         noun
# -------------------------------------------------------------------------------------------------------
#
# Entity:      a ton
# Relation:    Measurements, as of weight or distance
# Dependency:  determiner
# POS:         determiner
# -------------------------------------------------------------------------------------------------------
#
# Entity:      one day
# Relation:    Absolute or relative dates or periods
# Dependency:  numeric modifier
# POS:         numeral
# -------------------------------------------------------------------------------------------------------
#
# Entity:      Venkat Viswanathan
# Relation:    People, including fictional
# Dependency:  compound
# POS:         proper noun
# -------------------------------------------------------------------------------------------------------
#
# Entity:      Carnegie Mellon University
# Relation:    Companies, agencies, institutions, etc.
# Dependency:  compound
# POS:         proper noun
# -------------------------------------------------------------------------------------------------------
#
# Entity:      three-year
# Relation:    Absolute or relative dates or periods
# Dependency:  numeric modifier
# POS:         numeral
# -------------------------------------------------------------------------------------------------------
#
# Entity:      Viswanathan
# Relation:    People, including fictional
# Dependency:  nominal subject
# POS:         proper noun
# -------------------------------------------------------------------------------------------------------
#
# Entity:      54%
# Relation:    Percentage, including "%"
# Dependency:  numeric modifier
# POS:         numeral
# -------------------------------------------------------------------------------------------------------
#
# Entity:      56%
# Relation:    Percentage, including "%"
# Dependency:  numeric modifier
# POS:         numeral
# -------------------------------------------------------------------------------------------------------
#
# Entity:      69%
# Relation:    Percentage, including "%"
# Dependency:  numeric modifier
# POS:         numeral
# -------------------------------------------------------------------------------------------------------
#
# Entity:      Andrew Baglino
# Relation:    People, including fictional
# Dependency:  compound
# POS:         proper noun
# -------------------------------------------------------------------------------------------------------
#
# Entity:      128
# Relation:    Monetary values, including unit
# Dependency:  numeric modifier
# POS:         numeral
# -------------------------------------------------------------------------------------------------------
#
# Entity:      2019
# Relation:    Absolute or relative dates or periods
# Dependency:  object of preposition
# POS:         numeral
# -------------------------------------------------------------------------------------------------------
#
# Entity:      Berlin
# Relation:    Countries, cities, states
# Dependency:  object of preposition
# POS:         proper noun
# -------------------------------------------------------------------------------------------------------
#
# Entity:      Battery Cell ‘Leap
# Relation:    Objects, vehicles, foods, etc. (not services)
# Dependency:  compound
# POS:         noun
# -------------------------------------------------------------------------------------------------------
#
# Entity:      Asian
# Relation:    Nationalities or religious or political groups
# Dependency:  adjectival modifier
# POS:         adjective
# -------------------------------------------------------------------------------------------------------
#
# Entity:      Panasonic Corp.
# Relation:    Companies, agencies, institutions, etc.
# Dependency:  compound
# POS:         proper noun
# -------------------------------------------------------------------------------------------------------
#
# Entity:      LG Chem Ltd.
# Relation:    Companies, agencies, institutions, etc.
# Dependency:  compound
# POS:         proper noun
# -------------------------------------------------------------------------------------------------------
#
# Entity:      Monday
# Relation:    Absolute or relative dates or periods
# Dependency:  noun phrase as adverbial modifier
# POS:         proper noun
# -------------------------------------------------------------------------------------------------------
#
# Entity:      2022
# Relation:    Absolute or relative dates or periods
# Dependency:  object of preposition
# POS:         numeral
# -------------------------------------------------------------------------------------------------------
#
# Entity:      Tony Posawatz
# Relation:    People, including fictional
# Dependency:  compound
# POS:         proper noun
# -------------------------------------------------------------------------------------------------------
#
# Entity:      General Motors Co.’s
# Relation:    Companies, agencies, institutions, etc.
# Dependency:  compound
# POS:         proper noun
# -------------------------------------------------------------------------------------------------------
#
# Entity:      Chevrolet
# Relation:    Companies, agencies, institutions, etc.
# Dependency:  compound
# POS:         proper noun
# -------------------------------------------------------------------------------------------------------
#
# Entity:      Lucid Motors Inc.
# Relation:    Companies, agencies, institutions, etc.
# Dependency:  compound
# POS:         proper noun
# -------------------------------------------------------------------------------------------------------
#
# Entity:      Osaka
# Relation:    Countries, cities, states
# Dependency:  noun phrase as adverbial modifier
# POS:         proper noun
# -------------------------------------------------------------------------------------------------------
#
# Entity:      Panasonic
# Relation:    Companies, agencies, institutions, etc.
# Dependency:  attribute
# POS:         proper noun
# -------------------------------------------------------------------------------------------------------
#
# Entity:      Contemporary Amperex Technology Co.
# Relation:    Companies, agencies, institutions, etc.
# Dependency:  compound
# POS:         proper noun
# -------------------------------------------------------------------------------------------------------
#
# Entity:      CATL
# Relation:    Companies, agencies, institutions, etc.
# Dependency:  conjunct
# POS:         proper noun
# -------------------------------------------------------------------------------------------------------
#
# Entity:      China
# Relation:    Countries, cities, states
# Dependency:  possession modifier
# POS:         proper noun
# -------------------------------------------------------------------------------------------------------
#
# Entity:      Fujian
# Relation:    Countries, cities, states
# Dependency:  compound
# POS:         proper noun
# -------------------------------------------------------------------------------------------------------
#
# Entity:      South Korea’s
# Relation:    Countries, cities, states
# Dependency:  compound
# POS:         proper noun
# -------------------------------------------------------------------------------------------------------
#
# Entity:      LG Chem
# Relation:    Companies, agencies, institutions, etc.
# Dependency:  compound
# POS:         proper noun
# -------------------------------------------------------------------------------------------------------
#
# Entity:      Slide
# Relation:    Objects, vehicles, foods, etc. (not services)
# Dependency:  appositional modifier
# POS:         proper noun
# -------------------------------------------------------------------------------------------------------
#
# Entity:      Model S
# Relation:    Objects, vehicles, foods, etc. (not services)
# Dependency:  compound
# POS:         proper noun
# -------------------------------------------------------------------------------------------------------
#
# Entity:      520 miles
# Relation:    Measurements, as of weight or distance
# Dependency:  numeric modifier
# POS:         numeral
# -------------------------------------------------------------------------------------------------------
#
# Entity:      late 2021
# Relation:    Absolute or relative dates or periods
# Dependency:  adjectival modifier
# POS:         adjective
# -------------------------------------------------------------------------------------------------------
#
# Entity:      three-hour
# Relation:    Times smaller than a day
# Dependency:  numeric modifier
# POS:         numeral
# -------------------------------------------------------------------------------------------------------
#
# Entity:      Robyn Denholm
# Relation:    People, including fictional
# Dependency:  compound
# POS:         proper noun
# -------------------------------------------------------------------------------------------------------
#
# Entity:      30% to 40%
# Relation:    Percentage, including "%"
# Dependency:  modifier of quantifier
# POS:         numeral
# -------------------------------------------------------------------------------------------------------
#
# Entity:      500,000
# Relation:    Numerals that do not fall under another type
# Dependency:  numeric modifier
# POS:         numeral
# -------------------------------------------------------------------------------------------------------
#
# Entity:      2020
# Relation:    Absolute or relative dates or periods
# Dependency:  object of preposition
# POS:         numeral
# -------------------------------------------------------------------------------------------------------
#
# Entity:      about 36%
# Relation:    Percentage, including "%"
# Dependency:  adverbial modifier
# POS:         adposition
# -------------------------------------------------------------------------------------------------------
#
# Entity:      July
# Relation:    Absolute or relative dates or periods
# Dependency:  object of preposition
# POS:         proper noun
# -------------------------------------------------------------------------------------------------------
#
# Entity:      early in the year
# Relation:    Absolute or relative dates or periods
# Dependency:  adverbial modifier
# POS:         adverb
# -------------------------------------------------------------------------------------------------------
#
# Entity:      about 17%
# Relation:    Percentage, including "%"
# Dependency:  adverbial modifier
# POS:         adposition
# -------------------------------------------------------------------------------------------------------
#
# Entity:      75 million
# Relation:    Numerals that do not fall under another type
# Dependency:  compound
# POS:         numeral
# -------------------------------------------------------------------------------------------------------
#
# Entity:      90 million
# Relation:    Numerals that do not fall under another type
# Dependency:  compound
# POS:         numeral
# -------------------------------------------------------------------------------------------------------
#
# Entity:      last year
# Relation:    Absolute or relative dates or periods
# Dependency:  adjectival modifier
# POS:         adjective
# -------------------------------------------------------------------------------------------------------
#
# Entity:      LMC Automotive
# Relation:    Companies, agencies, institutions, etc.
# Dependency:  compound
# POS:         proper noun
# -------------------------------------------------------------------------------------------------------
#
# Entity:      $4.3 billion
# Relation:    Monetary values, including unit
# Dependency:  modifier of quantifier
# POS:         symbol
# -------------------------------------------------------------------------------------------------------
#
# Entity:      Bill Gates
# Relation:    People, including fictional
# Dependency:  modifier of nominal
# POS:         proper noun
# -------------------------------------------------------------------------------------------------------
#
# Entity:      QuantumScape
# Relation:    Companies, agencies, institutions, etc.
# Dependency:  object predicate
# POS:         proper noun
# -------------------------------------------------------------------------------------------------------
#
# Entity:      Medium Editor
# Relation:    Companies, agencies, institutions, etc.
# Dependency:  compound
# POS:         proper noun
# -------------------------------------------------------------------------------------------------------
#
# Entity:      Steve LeVine
# Relation:    People, including fictional
# Dependency:  compound
# POS:         proper noun
# -------------------------------------------------------------------------------------------------------
#
# Entity:      10-year-old
# Relation:    Absolute or relative dates or periods
# Dependency:  noun phrase as adverbial modifier
# POS:         numeral
# -------------------------------------------------------------------------------------------------------
#
# Entity:      Volkswagen AG
# Relation:    Companies, agencies, institutions, etc.
# Dependency:  compound
# POS:         proper noun
# -------------------------------------------------------------------------------------------------------
#
# Entity:      Sept. 3
# Relation:    Absolute or relative dates or periods
# Dependency:  object of preposition
# POS:         proper noun
# -------------------------------------------------------------------------------------------------------
#
# Entity:      the New York Stock Exchange
# Relation:    Companies, agencies, institutions, etc.
# Dependency:  determiner
# POS:         determiner
# -------------------------------------------------------------------------------------------------------
#
# Entity:      Kensington Capital Acquisition Corp
# Relation:    Companies, agencies, institutions, etc.
# Dependency:  compound
# POS:         proper noun
# -------------------------------------------------------------------------------------------------------
#
# Entity:      Reuters
# Relation:    Companies, agencies, institutions, etc.
# Dependency:  appositional modifier
# POS:         proper noun
# -------------------------------------------------------------------------------------------------------
#
# Entity:      Jagdeep Singh
# Relation:    People, including fictional
# Dependency:  compound
# POS:         proper noun
# -------------------------------------------------------------------------------------------------------
#
# Entity:      more than $500 million
# Relation:    Monetary values, including unit
# Dependency:  adjectival modifier
# POS:         adjective
# -------------------------------------------------------------------------------------------------------
#
# Entity:      Fidelity Management
# Relation:    Companies, agencies, institutions, etc.
# Dependency:  compound
# POS:         proper noun
# -------------------------------------------------------------------------------------------------------
#
# Entity:      Volkswagen
# Relation:    Companies, agencies, institutions, etc.
# Dependency:  nominal subject
# POS:         proper noun
# -------------------------------------------------------------------------------------------------------
#
# Entity:      $300 million
# Relation:    Monetary values, including unit
# Dependency:  modifier of quantifier
# POS:         symbol
# -------------------------------------------------------------------------------------------------------
#
# Entity:      2025
# Relation:    Absolute or relative dates or periods
# Dependency:  object of preposition
# POS:         numeral
# -------------------------------------------------------------------------------------------------------
#
# Entity:      EV
# Relation:    Companies, agencies, institutions, etc.
# Dependency:  compound
# POS:         noun
# -------------------------------------------------------------------------------------------------------
#
# Entity:      LeVine
# Relation:    People, including fictional
# Dependency:  object of preposition
# POS:         proper noun
# -------------------------------------------------------------------------------------------------------
#
# Entity:      TESLA
# Relation:    Companies, agencies, institutions, etc.
# Dependency:  None
# POS:         proper noun
# -------------------------------------------------------------------------------------------------------
#
# Entity:      Singh
# Relation:    People, including fictional
# Dependency:  object of preposition
# POS:         proper noun
# -------------------------------------------------------------------------------------------------------
#
# Entity:      Sept. 2020
# Relation:    Absolute or relative dates or periods
# Dependency:  modifier of nominal
# POS:         proper noun
# -------------------------------------------------------------------------------------------------------
#
# Entity:      Investor Presentation
# Relation:    Named hurricanes, battles, wars, sports events, etc.
# Dependency:  compound
# POS:         proper noun
# -------------------------------------------------------------------------------------------------------
#
# Entity:      15 minutes
# Relation:    Times smaller than a day
# Dependency:  numeric modifier
# POS:         numeral
# -------------------------------------------------------------------------------------------------------
#
# Entity:      about 90%
# Relation:    Percentage, including "%"
# Dependency:  modifier of quantifier
# POS:         adverb
# -------------------------------------------------------------------------------------------------------
#
# Entity:      EVs
# Relation:    Companies, agencies, institutions, etc.
# Dependency:  object of preposition
# POS:         noun
# -------------------------------------------------------------------------------------------------------
#
# Entity:      "million-dollar
# Relation:    Monetary values, including unit
# Dependency:  punctuation
# POS:         punctuation
# -------------------------------------------------------------------------------------------------------
#
# Entity:      a million miles
# Relation:    Measurements, as of weight or distance
# Dependency:  modifier of quantifier
# POS:         determiner
# -------------------------------------------------------------------------------------------------------
#
# Entity:      one
# Relation:    Numerals that do not fall under another type
# Dependency:  numeric modifier
# POS:         numeral
# -------------------------------------------------------------------------------------------------------
#
# Entity:      496%
# Relation:    Percentage, including "%"
# Dependency:  numeric modifier
# POS:         numeral
# -------------------------------------------------------------------------------------------------------
#
# Entity:      Aug. 31
# Relation:    Absolute or relative dates or periods
# Dependency:  object of preposition
# POS:         proper noun
# -------------------------------------------------------------------------------------------------------
#
# Entity:      POWELL
# Relation:    People, including fictional
# Dependency:  object of preposition
# POS:         proper noun
# -------------------------------------------------------------------------------------------------------
#
# Entity:      the last decade
# Relation:    Absolute or relative dates or periods
# Dependency:  determiner
# POS:         determiner
# -------------------------------------------------------------------------------------------------------
#
# Entity:      Gates
# Relation:    Companies, agencies, institutions, etc.
# Dependency:  conjunct
# POS:         proper noun
# -------------------------------------------------------------------------------------------------------
#
# Entity:      the past few months
# Relation:    Absolute or relative dates or periods
# Dependency:  determiner
# POS:         determiner
# -------------------------------------------------------------------------------------------------------
#
# Entity:      Microsoft
# Relation:    Companies, agencies, institutions, etc.
# Dependency:  compound
# POS:         proper noun
# -------------------------------------------------------------------------------------------------------
#
# Entity:      Twitter
# Relation:    Companies, agencies, institutions, etc.
# Dependency:  object of preposition
# POS:         proper noun
# -------------------------------------------------------------------------------------------------------
#
# Entity:      The U.S. Economy
# Relation:    Companies, agencies, institutions, etc.
# Dependency:  determiner
# POS:         determiner
# -------------------------------------------------------------------------------------------------------
#
# Entity:      $4.5M
# Relation:    Monetary values, including unit
# Dependency:  modifier of quantifier
# POS:         symbol
# -------------------------------------------------------------------------------------------------------
#
# Entity:      Spare
# Relation:    Buildings, airports, highways, bridges, etc.
# Dependency:  object of preposition
# POS:         noun
# -------------------------------------------------------------------------------------------------------
#
# Entity:      Ferrari
# Relation:    Companies, agencies, institutions, etc.
# Dependency:  possession modifier
# POS:         proper noun
# -------------------------------------------------------------------------------------------------------

# %% [markdown]
# # 3. Events Identification
# Based on the article content identify if it cover specific event or not.

# %% [markdown]
# #### Assumption :
#     - Assuming event to be, in the given article any of it's sentences there are DATE and EVENT entities!

# %% [markdown]
# ### 3.1 Displaying even identification.

# %%
event_identification(new_content)
# Out:
# Event Title:
#
# Tesla rival? Bill Gates-backed electric vehicle battery startup comes into limelight
# -------------------------------------------------------------------------------------------------------
#
#
# Event sentence:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">In its
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Sept. 2020
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#
# <mark class="entity" style="background: #ffeb80; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Investor Presentation
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">EVENT</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     QuantumScape
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  said its lithium-metal solid-state battery could charge in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     15 minutes
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
# , cost less than most of
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     today
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# 's conventional batteries and allow mass-market EVs to travel
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     about 90%
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
#  further than contemporary
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     EVs
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , according to
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     LeVine
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# .
# </div></span>
# -------------------------------------------------------------------------------------------------------
#
#
# Event content:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">A
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     $4.3 billion
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bill Gates
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# -backed electric vehicle battery startup called
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     QuantumScape
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  could rival
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tesla
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , according to a
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Monday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  report from
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Medium Editor
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# -at-Large
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Steve LeVine
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# .</br>The
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     10-year-old
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     California
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  startup, also backed by
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Volkswagen AG
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , announced on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Sept. 3
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  that it will be going public on
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the New York Stock Exchange
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  under the ticker &quot;QS&quot; after merging with shell company
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Kensington Capital Acquisition Corp
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Reuters
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  reported at the time.</br>&quot;Our ambition is to be a [battery] supplier to the industry as a whole,&quot;
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     QuantumScape
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  founder and CEO
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Jagdeep Singh
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  told the outlet.</br>The battery maker raised
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     more than $500 million
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  from investors led by
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Fidelity Management
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  and Research ahead of the merger,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Reuters
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  reported.
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Volkswagen
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  has invested a total of
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     $300 million
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  in QuantumScape with the goal of starting a production line for the startup's batteries by
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2025
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercas

# %% [markdown]
# # 4. Sentiment Analysis
# Analyze each paragraph of the article and provide sentiment score for it based on Financial context of it.  Use "key" weight from "Named Entity Extraction" to provide the final article score.

# %% [markdown]
# #### Assumption :
#     - Using NLTK's 'VADER' sentiment analyser. Vader is trained on news data using lexicon-based approach and rates them as positive or negative.

# %% [markdown]
# ### 4.1. Displaying sentiment analysis:

# %%
sentiment_analysis(new_content)
# Out:
# Title:
# Amazon Tells Echelon Fitness to Stop Selling $500 Prime Bike
# -------------------------------------------------------------------------------------------------------
#
# Sentence:
# ---------
# Amazon.com Inc. told Echelon Fitness to stop selling an exercise bike that was promoted and branded as a product developed in partnership with the e-commerce giant.
#
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.076
# neu: 0.756
# pos: 0.168
# compound: 0.4019
#
#
#
# Sentence:
# ---------
# Echelon announced the EX-Prime Smart Connect Bike earlier this week and said it was developed “in collaboration with Amazon.”
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.0
# neu: 0.87
# pos: 0.13
# compound: 0.4019
#
#
#
# Sentence:
# ---------
# The machine was listed on Amazon’s website for $500, a steep discount to machines offered by Peloton Interactive Inc.
#
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.0
# neu: 1.0
# pos: 0.0
# compound: 0.0
#
#
#
# Sentence:
# ---------
# “This bike is not an Amazon product or related to Amazon Prime,” an Amazon spokeswoman wrote in an email late Tuesday.
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.202
# neu: 0.798
# pos: 0.0
# compound: -0.3724
#
#
#
# Sentence:
# ---------
# “Echelon does not have a formal partnership with Amazon.
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.0
# neu: 0.805
# pos: 0.195
# compound: 0.1779
#
#
#
# Sentence:
# ---------
# We are working with Echelon to clarify this in its communications, stop the sale of the product, and change the product branding.”
#
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.095
# neu: 0.905
# pos: 0.0
# compound: -0.296
#
#
#
# Sentence:
# ---------
# Amazon’s Prime subscription, which offers free shipping and other perks for an annual fee, has been one of the most successful offerings in e-commerce history.
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.0
# neu: 0.757
# pos: 0.243
# compound: 0.8122
#
#
#
# Sentence:
# ---------
# Products associated with the program often get a sales boost, especially on Amazon’s website.
#
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.0
# neu: 0.816
# pos: 0.184
# compound: 0.4019
#
#
#
# Sentence:
# ---------
# Echelon didn’t immediately respond to a request for comment.
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.0
# neu: 1.0
# pos: 0.0
# compound: 0.0
#
#
#
# Sentence:
# ---------
# However, the company’s original press release announcing the bike was no longer available online late Tuesday.
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.119
# neu: 0.757
# pos: 0.124
# compound: 0.0258
#
#
#
# Sentence:
# ---------
# On Amazon’s website, the product was also listed as “currently unavailable.”
#
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.0
# neu: 1.0
# pos: 0.0
# compound: 0.0
#
#
#
# Sentence:
# ---------
# Shares of Peloton fell as much as 6.7% early Tuesday on concern about new competition from Amazon.
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.0
# neu: 0.794
# pos: 0.206
# compound: 0.4404
#
#
#
# Sentence:
# ---------
# But the stock recovered to be down less than 1% at the close in New York.
#
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.0
# neu: 1.0
# pos: 0.0
# compound: 0.0
#
#
#
# Sentence:
# ---------
# “Other than a few cosmetic changes, the $500 bike is almost identical to Echelon’s $500 bike at Walmart.com, which has been available at Walmart.com since March and hasn’t had any noticeable impact to Peloton’s growth,” KeyBanc Capital Markets analyst Edward Yruma wrote in a note to investors.
#
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.0
# neu: 1.0
# pos: 0.0
# compound: 0.0
#
#
#
# Sentence:
# ---------
# (Updates to show Echelon press release no longer available in fifth paragraph)
#
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.167
# neu: 0.833
# pos: 0.0
# compound: -0.296
#
#
#
# Sentence:
# ---------
# For more articles like this, please visit us at bloomberg.com
#
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.0
# neu: 0.597
# pos: 0.403
# compound: 0.6601
#
#
#
# Sentence:
# ---------
# Subscribe now to stay ahead with the most trusted business news source.
#
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.0
# neu: 0.764
# pos: 0.236
# compound: 0.5256
#
#
#
# Sentence:
# ---------
# 2020 Bloomberg L.P.
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.0
# neu: 1.0
# pos: 0.0
# compound: 0.0
#
#
#
# Title:
# 3 “Strong Buy” Stocks That Are Flirting With a Bottom
# -------------------------------------------------------------------------------------------------------
#
# Sentence:
# ---------
# In the investing game, it’s not only about what you buy
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.0
# neu: 1.0
# pos: 0.0
# compound: 0.0
#
#
#
# Sentence:
# ---------
# ; it’s about when you buy it.
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.0
# neu: 1.0
# pos: 0.0
# compound: 0.0
#
#
#
# Sentence:
# ---------
# One of the most common pieces of advice thrown around the Street, “buy low” is touted as a tried-and-true tactic.
#
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.062
# neu: 0.938
# pos: 0.0
# compound: -0.0516
#
#
#
# Sentence:
# ---------
# Sure, the strategy seems simple.
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.0
# neu: 0.635
# pos: 0.365
# compound: 0.3182
#
#
#
# Sentence:
# ---------
# Stock prices naturally fluctuate on the basis of several factors like earnings results and the macro environment, amongst others, with investors trying to time the market and determine when stocks have hit a bottom.
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.0
# neu: 0.928
# pos: 0.072
# compound: 0.3612
#
#
#
# Sentence:
# ---------
# In practice, however, executing on this strategy is no easy task.
#
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.156
# neu: 0.638
# pos: 0.206
# compound: 0.1779
#
#
#
# Sentence:
# ---------
# On top of this, given the volatility that has ruled the markets over the last few weeks, how are investors supposed to gauge when a name is flirting with a bottom?
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.0
# neu: 0.882
# pos: 0.118
# compound: 0.3818
#
#
#
# Sentence:
# ---------
# That’s where the Wall Street pros come in.
#
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.0
# neu: 1.0
# pos: 0.0
# compound: 0.0
#
#
#
# Sentence:
# ---------
# These expert stock pickers have identified three compelling tickers whose current share prices land close to their 52-week lows.
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.082
# neu: 0.731
# pos: 0.187
# compound: 0.3182
#
#
#
# Sentence:
# ---------
# Noting that each is set to take back off on an upward trajectory, the analysts see an attractive entry point.
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.0
# neu: 0.868
# pos: 0.132
# compound: 0.4404
#
#
#
# Sentence:
# ---------
# Using TipRanks’ database, we found out that the analyst consensus has rated all three a Strong Buy, with major upside potential also on tap.
#
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.0
# neu: 0.87
# pos: 0.13
# compound: 0.5106
#
#
#
# Sentence:
# ---------
# Offering clear and actionable genetic results, Progenity specializes in providing testing services.
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.0
# neu: 0.809
# pos: 0.191
# compound: 0.3818
#
#
#
# Sentence:
# ---------
# The company started trading on Nasdaq in June and saw its shares tumbling 44% since then.
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.0
# neu: 0.872
# pos: 0.128
# compound: 0.296
#
#
#
# Sentence:
# ---------
# With shares changing hands for $8.11, several members of the Street recommend pulling the trigger before it heats up.
#
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.0
# neu: 0.783
# pos: 0.217
# compound: 0.5719
#
#
#
# Sentence:
# ---------
# Piper Sandler analyst Steven Mah points out that even against the backdrop of COVID-19, PROG managed to deliver with its Q2 2020 performance.
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.0
# neu: 1.0
# pos: 0.0
# compound: 0.0
#
#
#
# Sentence:
# ---------
# “We are encouraged by the recovery in late Q2 2020 with 75,000 accessioned tests (~79,000 in Q1 2020), driven by noninvasive prenatal testing (NIPT) and carrier screening,” the analyst noted.
#
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.0
# neu: 0.921
# pos: 0.079
# compound: 0.3612
#
#
#
# Sentence:
# ---------
# Expounding on this, Mah stated, “Progenity did not provide guidance, but June test volumes of ~28,000 were strong (Q1 2020 monthly average was ~26,000) which we believe showcases the durability of its reproductive tests and the success that Progenity has in co-marketing and attaching carrier screening to the more essential NIPT.
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.0
# neu: 0.838
# pos: 0.162
# compound: 0.8885
#
#
#
# Sentence:
# ---------
# Of note, despite the pandemic disruptions, Progenity was able to maintain its leading pre-COVID test turnaround times.”
#
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.0
# neu: 0.887
# pos: 0.113
# compound: 0.2584
#
#
#
# Sentence:
# ---------
# Additionally, health insurer Aetna is temporarily extending coverage of average-risk NIPT until year-end as a result of the pandemic, with the American College of Obstetricians and Gynecologists (ACOG) also expected to endorse average-risk in the future given its clinical utility, in Mah’s opinion.
#
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.0
# neu: 0.947
# pos: 0.053
# compound: 0.3182
#
#
#
# Sentence:
# ---------
# Reflecting another positive, the fourth generation NIPT (single-molecule counting assay) test was able to measure fetal fraction, a key milestone according to Mah, and will continue to be developed into 2021.
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.0
# neu: 0.89
# pos: 0.11
# compound: 0.5574
#
#
#
# Sentence:
# ---------
# As the technology could potentially be applied to DNA, RNA, epigenetic markers and proteins for additional clinical applications such as oncology, the analyst is looking forward to the completion of the preeclampsia verification in Q4 2020 and a possible 2H21 launch.
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.0
# neu: 1.0
# pos: 0.0
# compound: 0.0
#
#
#
# Sentence:
# ---------
# “We believe preeclampsia (~2.3 billion serviceable market) is a major differentiator for Progenity, allowing them to cross-sell across the full-continuum of reproductive testing,” the analyst added.
#
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.0
# neu: 1.0
# pos: 0.0
# compound: 0.0
#
#
#
# Sentence:
# ---------
# If that wasn’t enough, PROG signed its first GI Precision Medicine partnership agreement with a top-20 Pharma company in August.
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.0
# neu: 0.849
# pos: 0.151
# compound: 0.4939
#
#
#
# Sentence:
# ---------
# The Oral Biotherapeutic Delivery System (OBDS), an ingestible drug and device combination designed to precisely deliver biologics systemically through a needle-free liquid jet injection into the submucosal tissues of the small intestine, is set to be utilized as part of the collaboration.
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.0
# neu: 1.0
# pos: 0.0
# compound: 0.0
#
#
#
# Sentence:
# ---------
# Mah commented, “We believe Progenity can sign additional Pharma deals and look forward to the newsflow coming out on this front.”
#
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.0
# neu: 1.0
# pos: 0.0
# compound: 0.0
# Sentence:
# ---------
# To sum it all up, Mah said, “We believe Progenity shares are undervalued given the robust recovery in the core testing business and multiple upcoming growth catalysts.”
#
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.0
# neu: 0.769
# pos: 0.231
# compound: 0.7351
#
#
#
# Sentence:
# ---------
# To this end, Mah rates PROG an Overweight (i.e. Buy) along with a $17 price target.
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.152
# neu: 0.848
# pos: 0.0
# compound: -0.3612
#
#
#
# Sentence:
# ---------
# Should his thesis play out, a twelve-month gain of 105% could potentially be in the cards.
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.0
# neu: 0.691
# pos: 0.309
# compound: 0.7003
#
#
#
# Sentence:
# ---------
# (To watch Mah’s track record, click here)
#
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.0
# neu: 1.0
# pos: 0.0
# compound: 0.0
#
#
#
# Sentence:
# ---------
# Are other analysts in agreement?
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.0
# neu: 0.556
# pos: 0.444
# compound: 0.4939
#
#
#
# Sentence:
# ---------
# Only Buy ratings, 4, in fact, have been issued in the last three months.
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.0
# neu: 1.0
# pos: 0.0
# compound: 0.0
#
#
#
# Sentence:
# ---------
# Therefore, the message is clear: PROG is a Strong Buy.
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.0
# neu: 0.543
# pos: 0.457
# compound: 0.7096
#
#
#
# Sentence:
# ---------
# Given the $13.33 average price target, shares could climb 60% higher in the next year.
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.0
# neu: 0.864
# pos: 0.136
# compound: 0.296
#
#
#
# Sentence:
# ---------
# (See PROG stock analysis on TipRanks)
# Tactile Systems Technology (TCMD)
#
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.0
# neu: 1.0
# pos: 0.0
# compound: 0.0
#
#
#
# Sentence:
# ---------
# Developing at-home therapy devices, Tactile Systems Technology wants to provide new treatments for lymphedema, which occurs when the lymphatic system is impaired, disrupting normal transport of fluid within the body, and chronic venous insufficiency.
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.0
# neu: 1.0
# pos: 0.0
# compound: 0.0
#
#
#
# Sentence:
# ---------
# Down 52% year-to-date, its $32.67 share price lands close to its $29.47 52-week low.
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.129
# neu: 0.736
# pos: 0.135
# compound: 0.0258
#
#
#
# Sentence:
# ---------
# Thus, with business trends improving, the Street is pounding the table.
#
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.0
# neu: 0.781
# pos: 0.219
# compound: 0.4215
#
#
#
# Sentence:
# ---------
# Writing for Canaccord, analyst Cecilia Furlong acknowledges that the pandemic has hampered the company, with COVID-19 weighing on both volumes and sales.
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.0
# neu: 1.0
# pos: 0.0
# compound: 0.0
#
#
#
# Sentence:
# ---------
# In the second half of March, volumes were down 50% compared to the first half of the month, and TCMD’s patient volumes in April and May remained challenged.
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.049
# neu: 0.951
# pos: 0.0
# compound: -0.1027
#
#
#
# Sentence:
# ---------
# That being said, trends started to improve at the end of May.
#
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.0
# neu: 0.791
# pos: 0.209
# compound: 0.4404
#
#
#
# Sentence:
# ---------
# “Going forward, given the vast majority of TCMD’s clinician customers practice in outpatient or office-based settings, we remain positive on TCMD’s ability to demonstrate better insulation against COVID impacts and likely experience a greater bounce-back relative to overall med-tech volume trends, with TCMD further benefitting from its expanding using of technology to remotely engage with clinicians and support patients,” Furlong explained.
#
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.0
# neu: 0.733
# pos: 0.267
# compound: 0.9538
#
#
#
# Sentence:
# ---------
# The analyst added, “Furthermore, recent trends among some providers to prescribe Flexitouch (an advanced intermittent pneumatic compression device to self-manage lymphedema and nonhealing venous leg ulcers) earlier along the therapy process, as a means to reduce in-person contact, could provide upside near term, as well as potentially transition to a longer-term tailwind.”
#
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.0
# neu: 0.921
# pos: 0.079
# compound: 0.4767
#
#
#
# Sentence:
# ---------
# On top of this, Furlong is also optimistic about new CEO Dan Reuvers and the reprioritization of the company’s investment and market development efforts.
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.0
# neu: 0.843
# pos: 0.157
# compound: 0.4767
#
#
#
# Sentence:
# ---------
# TCMD will shift focus away from its acquired Airwear product line, with it redirecting investments toward its Flexitouch and Entre (a pneumatic compression device used to assist in the home management of chronic swelling and venous ulcers associated with lymphedema and chronic venous insufficiency) products.
#
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.0
# neu: 1.0
# pos: 0.0
# compound: 0.0
#
#
#
# Sentence:
# ---------
# “Given significant under-penetration in the lymphedema/phlebolymphedema market targeted by Flexitouch alongside the large patient population with limited treatment options today targeted by the firm’s Head & Neck platform, we view the combination of education and clinical data as key to further developing and penetrating these markets...
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.041
# neu: 0.921
# pos: 0.039
# compound: -0.0258
#
#
#
# Sentence:
# ---------
# Going forward, we expect management to continue to compile a broad base of clinical data to support reimbursement and drive broad adoption,” Furlong commented.
#
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.0
# neu: 0.891
# pos: 0.109
# compound: 0.4019
#
#
#
# Sentence:
# ---------
# All of this prompted Furlong to keep a Buy rating and $62 price target on the stock.
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.0
# neu: 1.0
# pos: 0.0
# compound: 0.0
#
#
#
# Sentence:
# ---------
# This target conveys her confidence in TCMD’s ability to soar 90% in the next year.
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.0
# neu: 0.699
# pos: 0.301
# compound: 0.6808
#
#
#
# Sentence:
# ---------
# (To watch Furlong’s track record, click here)
#
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.0
# neu: 1.0
# pos: 0.0
# compound: 0.0
#
#
#
# Sentence:
# ---------
# In general, other analysts are on the same page.
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.0
# neu: 1.0
# pos: 0.0
# compound: 0.0
#
#
#
# Sentence:
# ---------
# With 3 Buy ratings and 1 Hold, the word on the Street is that TCMD is a Strong Buy.
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.0
# neu: 0.82
# pos: 0.18
# compound: 0.5106
#
#
#
# Sentence:
# ---------
# The $62.33 average price target brings the upside potential to 91%.
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.0
# neu: 1.0
# pos: 0.0
# compound: 0.0
#
#
#
# Sentence:
# ---------
# (See TCMD stock analysis on TipRanks)
#
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.0
# neu: 1.0
# pos: 0.0
# compound: 0.0
#
#
#
# Sentence:
# ---------
# uniQure N.V. (QURE)
#
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.0
# neu: 1.0
# pos: 0.0
# compound: 0.0
#
#
#
# Sentence:
# ---------
# Last but not least we have uniQure, which delivers curative gene therapies that could potentially transform the lives of patients.
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.0
# neu: 1.0
# pos: 0.0
# compound: 0.0
#
#
#
# Sentence:
# ---------
# Even though shares have fallen 44% year-to-date to $40, not much higher than its 52-week low of $36.20, multiple analysts still have high hopes.
#
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.155
# neu: 0.676
# pos: 0.169
# compound: 0.1027
#
#
#
# Sentence:
# ---------
# Representing SVB Leerink, 5-star analyst Joseph Schwartz acknowledges that shares struggled after news broke of its collaboration and licensing agreement with CSL Behring for AMT-061, QURE’s gene therapy for Hemophilia B, he argues the “shareholder base turnover is likely now complete as investors and QURE shift focus to next-in-line AMT-130, its AAV5 gene therapy for Huntington
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.121
# neu: 0.794
# pos: 0.084
# compound: -0.34
#
#
#
# Sentence:
# ---------
# ’s Disease (HD).”
#
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.0
# neu: 1.0
# pos: 0.0
# compound: 0.0
#
#
#
# Sentence:
# ---------
# Schwartz further added, “With the M&A premium now out of the stock, we see the QURE’s current level as an attractive buying opportunity for those investors interested in the company’s up and coming CNS gene therapies, internal manufacturing, and robust intellectual property and knowhow.”
#
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.0
# neu: 0.734
# pos: 0.266
# compound: 0.9201
#
#
#
# Sentence:
# ---------
# Looking more closely at the agreement with CSL Behring, QURE will be tasked with the completion of the pivotal Phase 3 HOPE-B trial as well as the manufacturing process validation and manufacturing supply of AMT-061.
#
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.0
# neu: 0.858
# pos: 0.142
# compound: 0.6486
#
#
#
# Sentence:
# ---------
# According to management, 26-week Factor IX (FIX) data from all 54 patients enrolled in the trial remains on track, and topline data from the pivotal trial is still slated to read out by YE20.
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.0
# neu: 1.0
# pos: 0.0
# compound: 0.0
#
#
#
# Sentence:
# ---------
# It should be mentioned that in a Phase 2b dose-confirmation study, QURE reported 41% FIX activity out to one year.
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.0
# neu: 1.0
# pos: 0.0
# compound: 0.0
#
#
#
# Sentence:
# ---------
# Additionally, Schwartz points out that with HOPE-B progressing as planned, QURE has continued its manufacturing process validation work ahead of the anticipated BLA/MAA submissions in the U.S. and EU in 2021.
#
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.0
# neu: 1.0
# pos: 0.0
# compound: 0.0
#
#
#
# Sentence:
# ---------
# On top of this, as part of the deal, QURE is eligible to receive more than $2 billion including a $450 million upfront cash payment, $1.6 billion in regulatory and commercial milestones and double-digit royalties ranging up to the low-twenties percentage of net product sales.
#
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.0
# neu: 0.96
# pos: 0.04
# compound: 0.2023
#
#
#
# Sentence:
# ---------
# “With a strengthened cash position, QURE is well funded to rapidly advance CNS assets including AMT-130 (AAV5 gene therapy for Huntington
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.0
# neu: 0.72
# pos: 0.28
# compound: 0.6808
#
#
#
# Sentence:
# ---------
# ’s Disease (HD))
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.0
# neu: 1.0
# pos: 0.0
# compound: 0.0
#
#
#
# Sentence:
# ---------
# and AMT-150 (AAV gene therapy for Spinocerebellar Ataxia Type 3/
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.0
# neu: 1.0
# pos: 0.0
# compound: 0.0
#
#
#
# Sentence:
# ---------
# We continue to believe that as QURE’s CNS pipeline assets mature, the company could once again be an attractive partner to larger biopharma companies that have recently acquired many publicly traded gene therapy platforms with substantial manufacturing capabilities,” Schwartz noted.
#
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.0
# neu: 0.796
# pos: 0.204
# compound: 0.802
#
#
#
# Sentence:
# ---------
# Everything that QURE has going for it convinced Schwartz to reiterate an Outperform (i.e. Buy) rating.
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.0
# neu: 0.847
# pos: 0.153
# compound: 0.4019
#
#
#
# Sentence:
# ---------
# Along with the call, he attached a $67 price target, suggesting 68% upside potential from current levels.
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.0
# neu: 1.0
# pos: 0.0
# compound: 0.0
#
#
#
# Sentence:
# ---------
# (To watch Schwartz’s track record, click here)
#
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.0
# neu: 1.0
# pos: 0.0
# compound: 0.0
#
#
#
# Sentence:
# ---------
# What does the rest of the Street have to say?
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.0
# neu: 1.0
# pos: 0.0
# compound: 0.0
#
#
#
# Sentence:
# ---------
# 9 Buys and 3 Holds have been issued in the last three months, so the consensus rating is a Strong Buy.
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.0
# neu: 0.837
# pos: 0.163
# compound: 0.5106
#
#
#
# Sentence:
# ---------
# In addition, the $69.89 average price target indicates 75% upside potential.
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.0
# neu: 1.0
# pos: 0.0
# compound: 0.0
#
#
#
# Sentence:
# ---------
# (See QURE stock analysis on TipRanks)
# To find good ideas for beaten-down stocks trading at attractive valuations, visit TipRanks’
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.0
# neu: 0.746
# pos: 0.254
# compound: 0.7003
# Sentence:
# ---------
# Best Stocks to Buy, a newly launched tool that unites all of TipRanks’ equity insights.
#
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.0
# neu: 0.678
# pos: 0.322
# compound: 0.6908
#
#
#
# Sentence:
# ---------
# The opinions expressed in this article are solely those of the featured analysts.
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.0
# neu: 1.0
# pos: 0.0
# compound: 0.0
#
#
#
# Sentence:
# ---------
# The content is intended to be used for informational purposes only.
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.0
# neu: 1.0
# pos: 0.0
# compound: 0.0
#
#
#
# Sentence:
# ---------
# It is very important to do your own analysis before making any investment.
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.0
# neu: 0.851
# pos: 0.149
# compound: 0.2716
#
#
#
# Title:
# Tesla’s Battery Day Letdown Risks $320 Billion Stock Gain
# -------------------------------------------------------------------------------------------------------
#
# Sentence:
# ---------
# Tesla Inc.’s highly anticipated “Battery Day” fell short of expectations that helped fuel its $320 billion surge in market value this year, with Elon Musk outlining grandiose goals that will take time to pull off.
#
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.0
# neu: 0.934
# pos: 0.066
# compound: 0.34
#
#
#
# Sentence:
# ---------
# The chief executive officer laid out a plan Tuesday to build a $25,000 car and cut battery costs in half over the next three years.
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.087
# neu: 0.913
# pos: 0.0
# compound: -0.2732
#
#
#
# Sentence:
# ---------
# Analysts said while the technology and manufacturing innovations outlined were impressive, Tesla’s valuation already reflected its ability to disrupt and that investors may be let down by the lack of surprises at the much-hyped event.
#
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.056
# neu: 0.76
# pos: 0.184
# compound: 0.6369
#
#
#
# Sentence:
# ---------
# “With the Battery Day in the rearview, we think there is a lack of upcoming catalysts and are cautious about demand given the recessionary environment,” Robert W. Baird’s Ben Kallo wrote in a Wednesday report naming Tesla a bearish “fresh pick.”
#
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.129
# neu: 0.871
# pos: 0.0
# compound: -0.4939
#
#
#
# Sentence:
# ---------
# That was echoed by Patrick Hummel, an analyst at UBS with a “neutral” rating on the stock, who said in a research note Tesla’s leadership in battery technology and costs is fully valued into the stock.
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.0
# neu: 0.912
# pos: 0.088
# compound: 0.4927
#
#
#
# Sentence:
# ---------
# “Given the high expectations into the event, we think the market will initially respond negatively to the relatively long timelines of the innovations and the lack of granularity,” he wrote.
#
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.073
# neu: 0.927
# pos: 0.0
# compound: -0.3182
#
#
#
# Sentence:
# ---------
# Tesla shares fell 5.4% to $401.19 as of 9:50 a.m. in New York.
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.0
# neu: 0.845
# pos: 0.155
# compound: 0.296
#
#
#
# Sentence:
# ---------
# The stock has soared about 400% this year.
#
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.0
# neu: 1.0
# pos: 0.0
# compound: 0.0
#
#
#
# Sentence:
# ---------
# Musk, 49, said Tesla wants to eventually produce 20 million cars a year.
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.0
# neu: 1.0
# pos: 0.0
# compound: 0.0
#
#
#
# Sentence:
# ---------
# He described a series of innovations that include using dry-electrode technology and making the battery a structural element of the car.
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.0
# neu: 1.0
# pos: 0.0
# compound: 0.0
#
#
#
# Sentence:
# ---------
# Those incremental and longer-term advances belied expectations for a blockbuster leap forward, which Musk himself played up in the weeks leading up to the event.
#
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.0
# neu: 0.777
# pos: 0.223
# compound: 0.743
#
#
#
# Sentence:
# ---------
# “The challenge with the stock is that everything they are talking about is three years away,” said Gene Munster, managing director of Loup Ventures.
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.0
# neu: 0.947
# pos: 0.053
# compound: 0.0772
#
#
#
# Sentence:
# ---------
# “I think traditional auto is in an even tighter spot, but Tesla investors want this tomorrow.”
#
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.0
# neu: 0.912
# pos: 0.088
# compound: 0.1154
#
#
#
# Sentence:
# ---------
# Vertical-integration improvements -- from making its own battery cells on a pilot line at its factory in Fremont, California, to owning rights to a lithium clay deposit in Nevada -- are designed to allow Tesla to cut costs and offer a cheap car as soon as 2023.
#
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.044
# neu: 0.867
# pos: 0.089
# compound: 0.2732
#
#
#
# Sentence:
# ---------
# “This has always been our dream from the very beginning,” Musk said at the event showcasing Tesla’s battery technology.
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.0
# neu: 0.9
# pos: 0.1
# compound: 0.25
#
#
#
# Sentence:
# ---------
# “In about three years from now, we are confident we can make a compelling $25,000 electric vehicle that is also fully autonomous.”
#
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.0
# neu: 0.788
# pos: 0.212
# compound: 0.6249
#
#
#
# Sentence:
# ---------
# Halving Battery Costs
# Musk, 49, is teasing prospects for a cheaper mystery model without ever having really delivered on the $35,000 price point he had long promised for the Model 3.
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.039
# neu: 0.818
# pos: 0.142
# compound: 0.5267
#
#
#
# Sentence:
# ---------
# Three years after Tesla started taking orders for the car in early 2016, the CEO announced plans to close most of Tesla’s stores as a cost-saving measure, allowing him to offer the car at that cost.
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.0
# neu: 1.0
# pos: 0.0
# compound: 0.0
#
#
#
# Sentence:
# ---------
# He backtracked 10 days later, and the cheapest Model 3 available now is $37,990.
#
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.0
# neu: 1.0
# pos: 0.0
# compound: 0.0
#
#
#
# Sentence:
# ---------
# Making a truly mass-market electric car and boosting Tesla’s current annual production to 20 million cars will require vastly more batteries than are currently being produced from a handful of suppliers around the world.
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.0
# neu: 0.85
# pos: 0.15
# compound: 0.6486
#
#
#
# Sentence:
# ---------
# So Musk plans to expand global capacity by manufacturing battery cells in-house to supplement what it can buy.
#
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.0
# neu: 0.881
# pos: 0.119
# compound: 0.3182
#
#
#
# Sentence:
# ---------
# “Today’s batteries can’t scale fast enough,” said Musk, who is driven in part by the need to find sustainable energy sources.
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.0
# neu: 0.905
# pos: 0.095
# compound: 0.2732
#
#
#
# Sentence:
# ---------
# “There’s a clear path to success but a ton of work to do.”
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.0
# neu: 0.684
# pos: 0.316
# compound: 0.4854
#
#
#
# Sentence:
# ---------
# Musk said the gasoline-powered internal-combustion engine will one day be obsolete.
#
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.18
# neu: 0.82
# pos: 0.0
# compound: -0.296
#
#
#
# Sentence:
# ---------
# Musk described an “incredible series of innovations with varying levels of difficulty,” said Venkat Viswanathan, a battery expert at Carnegie Mellon University.
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.0
# neu: 1.0
# pos: 0.0
# compound: 0.0
#
#
#
# Sentence:
# ---------
# While battery-manufacturing advances are feasible and deliverable in the three-year time frame, Viswanathan thinks that chemistry developments will take a longer.
#
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.0
# neu: 1.0
# pos: 0.0
# compound: 0.0
#
#
#
# Sentence:
# ---------
# If the planned innovations pay off, vehicle range could increase 54%, cost could decrease 56% and investment in gigafactories could decline 69%, said Andrew Baglino, Tesla’s senior vice president for powertrain and energy engineering.
#
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.038
# neu: 0.842
# pos: 0.12
# compound: 0.4588
#
#
#
# Sentence:
# ---------
# estimates Tesla’s pack prices were $128/kWh in 2019.
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.0
# neu: 1.0
# pos: 0.0
# compound: 0.0
#
#
#
# Sentence:
# ---------
# A 56% cost reduction would bring prices down to $56/kWh.
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.0
# neu: 1.0
# pos: 0.0
# compound: 0.0
#
#
#
# Sentence:
# ---------
# In addition to the pilot line for battery-cell production in Fremont, and Musk said the company also will make cells at the factory that is under construction in Berlin.
#
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.0
# neu: 1.0
# pos: 0.0
# compound: 0.0
#
#
#
# Sentence:
# ---------
# Battery Cell ‘Leap’
# Most global automakers have shied away from making their own battery cells, citing the high investment costs and their lack of expertise in an industry dominated mostly by Asian electronics manufactures such as Panasonic Corp. and LG Chem Ltd.
# Musk said in a tweet Monday that Tesla will need to start producing its own battery cells to support its various products, even as it ramps up purchases from outside suppliers.
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.031
# neu: 0.933
# pos: 0.036
# compound: 0.1027
#
#
#
# Sentence:
# ---------
# He wrote that the company expects significant shortages of cells in 2022 and beyond unless it ramps up output of its own.
#
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.068
# neu: 0.855
# pos: 0.077
# compound: 0.0516
#
#
#
# Sentence:
# ---------
# “I’m really surprised that they’re taking that leap themselves,” said Tony Posawatz, a consultant who led development of General Motors Co.’s plug-in hybrid Chevrolet Volt and now sits on the board of Lucid Motors Inc., a Tesla rival.
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.0
# neu: 0.941
# pos: 0.059
# compound: 0.2944
# Sentence:
# ---------
# “I think this is going to be a bit harder than what they think, and I don’t think we’ll see a lot of volume out of that for quite some time.”
#
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.0
# neu: 1.0
# pos: 0.0
# compound: 0.0
#
#
#
# Sentence:
# ---------
# most important and long-standing partner on batteries is Osaka-based Panasonic, but it also has smaller-scale agreements with Contemporary Amperex Technology Co., or CATL, in China’s Fujian province and South Korea’s LG Chem.
#
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.0
# neu: 0.877
# pos: 0.123
# compound: 0.4933
#
#
#
# Sentence:
# ---------
# Read more: LG Chem, Panasonic Slide as Tesla Looks to Lower Battery Costs
#
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.155
# neu: 0.845
# pos: 0.0
# compound: -0.296
#
#
#
# Sentence:
# ---------
# The highly technical Battery Day presentation included several nuggets of news that were overshadowed by the talk of cathodes and electrolytes.
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.0
# neu: 1.0
# pos: 0.0
# compound: 0.0
#
#
#
# Sentence:
# ---------
# One example: The “Plaid” version of the Model S sedan -- with a range of 520 miles -- is now available to order, though the vehicle isn’t expected to go on sales until late 2021.
#
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.0
# neu: 1.0
# pos: 0.0
# compound: 0.0
#
#
#
# Sentence:
# ---------
# Tuesday’s three-hour event began with the annual shareholder meeting, held outside to allow for social distancing.
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.0
# neu: 0.888
# pos: 0.112
# compound: 0.2263
#
#
#
# Sentence:
# ---------
# Shareholders sat in Tesla cars in a parking lot, beeping loudly instead of cheering as Musk spoke.
#
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.0
# neu: 0.82
# pos: 0.18
# compound: 0.5106
#
#
#
# Sentence:
# ---------
# Investors voted to re-elect Musk and chairman Robyn Denholm to the board and voted against resolutions that would have required more transparency about human rights in the supply chain and the use of arbitration with employees.
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.0
# neu: 1.0
# pos: 0.0
# compound: 0.0
#
#
#
# Sentence:
# ---------
# One shareholder resolution, which requires Tesla to adopt a simple majority vote, did pass.
#
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.0
# neu: 0.876
# pos: 0.124
# compound: 0.1779
#
#
#
# Sentence:
# ---------
# Musk told shareholders he expects to see deliveries grow on the order of 30% to 40% this year, reaffirming Tesla’s forecast at a time when automakers are struggling to recover from the coronavirus pandemic.
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.08
# neu: 0.92
# pos: 0.0
# compound: -0.4215
#
#
#
# Sentence:
# ---------
# “While the rest of the industry has gone down, Tesla has gone up,” he said.
#
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.0
# neu: 1.0
# pos: 0.0
# compound: 0.0
#
#
#
# Sentence:
# ---------
# Tesla has said it anticipates delivering 500,000 vehicles in 2020, up about 36% from 2019.
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.0
# neu: 1.0
# pos: 0.0
# compound: 0.0
#
#
#
# Sentence:
# ---------
# In July, the electric-car maker said achieving that goal would be “more difficult” due to a pandemic-related production shutdown early in the year.
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.0
# neu: 1.0
# pos: 0.0
# compound: 0.0
#
#
#
# Sentence:
# ---------
# Global sales are projected to drop about 17% this year to 75 million from 90 million last year, according to research firm LMC Automotive.
#
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.084
# neu: 0.916
# pos: 0.0
# compound: -0.2732
#
#
#
# Sentence:
# ---------
# (Updates with additional analyst comment in fourth paragraph and opening shares in fifth paragraph.)
#
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.0
# neu: 0.855
# pos: 0.145
# compound: 0.296
#
#
#
# Sentence:
# ---------
# For more articles like this, please visit us at bloomberg.com
#
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.0
# neu: 0.597
# pos: 0.403
# compound: 0.6601
#
#
#
# Sentence:
# ---------
# Subscribe now to stay ahead with the most trusted business news source.
#
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.0
# neu: 0.764
# pos: 0.236
# compound: 0.5256
#
#
#
# Sentence:
# ---------
# 2020 Bloomberg L.P.
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.0
# neu: 1.0
# pos: 0.0
# compound: 0.0
#
#
#
# Title:
# Tesla rival? Bill Gates-backed electric vehicle battery startup comes into limelight
# -------------------------------------------------------------------------------------------------------
#
# Sentence:
# ---------
# A $4.3 billion Bill Gates-backed electric vehicle battery startup called QuantumScape could rival Tesla, according to a Monday report from Medium Editor-at-Large Steve LeVine.
#
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.0
# neu: 1.0
# pos: 0.0
# compound: 0.0
#
#
#
# Sentence:
# ---------
# The 10-year-old California startup, also backed by Volkswagen AG, announced on Sept. 3 that it will be going public on the New York Stock Exchange under the ticker "QS" after merging with shell company Kensington Capital Acquisition Corp, Reuters reported at the time.
#
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.0
# neu: 0.974
# pos: 0.026
# compound: 0.0258
#
#
#
# Sentence:
# ---------
# "Our ambition is to be a [battery] supplier to the industry as a whole," QuantumScape founder and CEO Jagdeep Singh told the outlet.
#
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.0
# neu: 1.0
# pos: 0.0
# compound: 0.0
#
#
#
# Sentence:
# ---------
# The battery maker raised more than $500 million from investors led by Fidelity Management and Research ahead of the merger, Reuters reported.
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.0
# neu: 1.0
# pos: 0.0
# compound: 0.0
#
#
#
# Sentence:
# ---------
# Volkswagen has invested a total of $300 million in QuantumScape with the goal of starting a production line for the startup's batteries by 2025.
#
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.0
# neu: 1.0
# pos: 0.0
# compound: 0.0
#
#
#
# Sentence:
# ---------
# Those investments came despite the fact that QuantumScape reportedly lacks verified evidence to support its claim that it is on track to produce an EV battery using pure metallic lithium, signifying a level of blind trust from investors, according to LeVine.
#
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.059
# neu: 0.81
# pos: 0.131
# compound: 0.5106
#
#
#
# Sentence:
# ---------
# NOTCHES VICTORY IN CASE OF EX-WORKER ACCUSED OF SHARING COMPANY DATA
# Singh, the QuantumScape CEO, told LeVine that the company is making batteries that use "'electrochemically distilled' lithium," the purest lithium you can have," adding that it "is also the most energy-dense configuration."
#
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.062
# neu: 0.864
# pos: 0.074
# compound: 0.1531
#
#
#
# Sentence:
# ---------
# In its Sept. 2020 Investor Presentation, QuantumScape said its lithium-metal solid-state battery could charge in 15 minutes, cost less than most of today's conventional batteries and allow mass-market EVs to travel about 90% further than contemporary EVs, according to LeVine.
#
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.0
# neu: 0.954
# pos: 0.046
# compound: 0.2263
#
#
#
# Sentence:
# ---------
# Almost every EV on the market today uses lithium-ion batteries.
#
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.0
# neu: 1.0
# pos: 0.0
# compound: 0.0
#
#
#
# Sentence:
# ---------
# Tesla founder and CEO Elon Musk is expected to unveil a "million-dollar battery" soon — perhaps during the company's Tuesday "Battery Day" event.
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.0
# neu: 1.0
# pos: 0.0
# compound: 0.0
#
#
#
# Sentence:
# ---------
# The new battery is speculated to last for a million miles after one charge.
#
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.0
# neu: 1.0
# pos: 0.0
# compound: 0.0
#
#
#
# Sentence:
# ---------
# QuantumScape's recent progress and high valuation marks the potential for new competition for Tesla.
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.0
# neu: 0.823
# pos: 0.177
# compound: 0.4215
#
#
#
# Sentence:
# ---------
# Tesla's stock has surged 496% this year through Aug. 31 in part due to Battery Day announcements.
#
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.0
# neu: 1.0
# pos: 0.0
# compound: 0.0
#
#
#
# Sentence:
# ---------
# STOCK MARKET LIVE UPDATE:
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.0
# neu: 1.0
# pos: 0.0
# compound: 0.0
#
#
#
# Sentence:
# ---------
# TECH REBOUNDS AHEAD OF POWELL, MNUCHIN TESTIMONY
#
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.0
# neu: 1.0
# pos: 0.0
# compound: 0.0
#
#
#
# Sentence:
# ---------
# Tesla has largely dominated the EV battery industry but has seen an increasing number of competitors pop up over the last decade or so.
#
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.0
# neu: 0.941
# pos: 0.059
# compound: 0.1154
#
#
#
# Sentence:
# ---------
# Musk and Gates have traded jabs over the past few months on social media and in interviews regarding coronavirus and EVs.
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.0
# neu: 1.0
# pos: 0.0
# compound: 0.0
#
#
#
# Sentence:
# ---------
# Most recently, the Microsoft founder expressed doubt that the EV and long-haul trucking industries could successfully intertwine.
#
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.121
# neu: 0.725
# pos: 0.155
# compound: 0.1779
#
#
#
# Sentence:
# ---------
# GET FOX BUSINESS ON THE GO BY CLICKING HERE
#
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.0
# neu: 1.0
# pos: 0.0
# compound: 0.0
#
#
#
# Sentence:
# ---------
# "The problem is that batteries are big and heavy," Gates wrote in a blog post.
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.172
# neu: 0.828
# pos: 0.0
# compound: -0.4019
#
#
#
# Sentence:
# ---------
# "Even with big breakthroughs in battery technology, electric vehicles will probably never be a practical solution for things like 18-wheelers, cargo ships and passenger jets.
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.074
# neu: 0.831
# pos: 0.094
# compound: 0.1376
#
#
#
# Sentence:
# ---------
# Electricity works when you need to cover short distances, but we need a different solution for heavy, long-haul vehicles."
#
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.0
# neu: 0.852
# pos: 0.148
# compound: 0.4497
#
#
#
# Sentence:
# ---------
# Musk said Gates has "no clue" about electric trucks in response to a question on Twitter.
#
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.136
# neu: 0.864
# pos: 0.0
# compound: -0.296
#
#
#
# Sentence:
# ---------
# READ MORE ON FOX BUSINESS BY CLICKING HERE
#
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.0
# neu: 1.0
# pos: 0.0
# compound: 0.0
#
#
#
# Sentence:
# ---------
# The U.S. Economy is Sucking Wind
# Uber Races Ahead to Get Self-Driving Cars on the Road
#
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.0
# neu: 1.0
# pos: 0.0
# compound: 0.0
#
#
#
# Sentence:
# ---------
# Have $4.5M to Spare?
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.0
# neu: 1.0
# pos: 0.0
# compound: 0.0
# Sentence:
# ---------
# Ferrari's Most Exclusive Car Up for Auction
#
# VADER Sentiment Scores:
# -----------------------
# neg: 0.0
# neu: 0.77
# pos: 0.23
# compound: 0.2006

# %% [markdown]
# ## Functions used in the Text Analysis

# %%
def get_article_content(url):
    
    """
    
    The Functions gets the Finance Yahoo url as a parameter and returns articles from the list of
    first page articles!
    
    Note: For simplicity getting only on the first page with no scrolling down the page!
    
    """

    returned_html = requests.get(url).text

    soup = BeautifulSoup(returned_html, 'html.parser')

    article_content = {}

    # After analyzing yahoo website, founded that articles are in <h3> tag with class = 'Mb(5px)'
    for each in soup.findAll("h3", {"class": "Mb(5px)"}):

        # Title of the article
        title = each.text

        # Link of the article
        href = 'https://finance.yahoo.com'+each.find('a')['href']

        # Requesting the article page
        returned_href = requests.get(href).text

        # Parsing the page
        soup_content_parser = BeautifulSoup(returned_href, 'html.parser')

        # After analyzing the page, founded that article content is in div and class 'caas-body' in paragraphs
        soup_content = soup_content_parser.find("div", {"class": "caas-body"})

        # Creating empty list to append each paragraph
        list_of_paras = []

        # Looping over each paragraph to extract the text
        for paragraph in soup_content.findAll("p"):
            list_of_paras.append(paragraph.text)

        # Concatinating the paragraphs
        whole_article = "\n".join(list_of_paras)

        # Appending to the dictionary
        article_content[title] = whole_article
   
    return article_content



def display_articles_and_entities(contents):
    for title, content in contents.items():
        print(f"TITLE: {title}")
        print("-------------------------------------------------------------------------------------------------------")
        print()
        print(f"CONTENT:")
        print("-------------------------------------------------------------------------------------------------------")
        spacy.displacy.render(nlp(content), jupyter=True, style='ent')
        print()
        print()
        print()
    




def entities_and_statistics(new_content):
    """
    The function gets contens in a dictionary type and makes entity statistics
    
    """
    
    list_entities = []
    count_entity_types = {}
    count_entities = {}
    entity_occurence_percent = {}

    for title, content in new_content.items():

        #  Tokenizing the string content
        doc = nlp(content)

        # Assigning all the founded entities in the current content
        all_entites = doc.ents

        # Iterating over each entity to extract make some statistics
        for entity in all_entites:
            list_entities.append(entity.text)

            if entity.label_+" ("+spacy.explain(entity.label_)+")" in count_entity_types:
                count_entity_types[entity.label_+" ("+spacy.explain(entity.label_)+")"] += 1
            else:
                count_entity_types[entity.label_+" ("+spacy.explain(entity.label_)+")"] = 1

            if entity.text in count_entities:
                count_entities[entity.text] += 1
            else:
                count_entities[entity.text] = 1

    # Sorting into reverse order 
    count_entity_types = {k: v for k, v in sorted(count_entity_types.items(), key=lambda item: item[1], reverse = True)}
    count_entities = {k: v for k, v in sorted(count_entities.items(), key=lambda item: item[1], reverse = True)}
    
    # Weight of each entity based on frequency of appearance 
    entity_occurence_percent = {k: f"{round(v/len(list_entities), 2) * 100}%" for k,v in count_entities.items()}
    
    return list_entities, count_entity_types, count_entities, entity_occurence_percent




def display_entity_statistics(all_entities, entity_type_frequency, entity_frequency, entity_occurence_percent):
    print("ENTITY STATISTICS:")
    print()
    print()
    print(f"Total entities: {len(list_entities)}")
    print("-------------------------------------------------------------------------------------------------------")
    print(f"Total unique entites: {len(set(list_entities))}")
    print("-------------------------------------------------------------------------------------------------------")
    print()
    print()
    print(f"Top 10 entity occurrences:")
    print("-------------------------------------------------------------------------------------------------------")
    for key, value in dict(itertools.islice(entity_frequency.items(), 10)).items():
        print(key, ":", value)
    print()
    print()
    print(f"Top 10 entity occurrences in percentage:")
    print("-------------------------------------------------------------------------------------------------------")
    for key, value in dict(itertools.islice(entity_occurence_percent.items(), 10)).items():
        print(key, ":", value)
    print()
    print()
    print(f"Entity type frequency:")
    print("-------------------------------------------------------------------------------------------------------")
    for key, value in entity_type_frequency.items():
        print(key, ":", value)
        
        
def generic_overview_num_values(contents):
    
    """
    This function gets contents as parameter and returns a dictionary for numeric values.
    
    Explation of key/value findings:
    -----------------------------
    value - by using 'Spacy' library, first we tokenize the text then with 'token.like_num' boolean,
    finding the words which are numeric. Then getting its left subtree first value and right subtree first value and concatenating into one string
    
    key - after finding numeric token getting its head token by token.head argument
    
    Example:
    -------
    {
    'target': '$ 67',
    'market': '~2.3 billion',
    }
    
    
    """
    
    total_keys = 0
    
    key_weights = {}

    key_value_pairs = dict()
    

    for title, content in contents.items():
        
        nlp_content = nlp(content)

        for sent in nlp_content.sents:
            
            # Removing stop words and punctuations
            sent_edited = nlp(" ".join([token.text for token in sent if not token.is_stop and not token.is_punct]))
            
            
            for token in sent_edited:

                # Finding numeric value
                if token.like_num:
                    
                    # Finding its left and right tree values
                    if len(list(token.lefts))>0:
                        left_tree_value  = list(token.lefts)[0].text
                    else:
                        left_tree_value = ""
                    if len(list(token.rights)) > 0:
                        right_tree_value  = list(token.rights)[0].text
                    else:
                        right_tree_value = ""
                    
                    # Concatinating
                    value = left_tree_value + " " + token.text + " "+ right_tree_value

                    # Finding Numeric values head
                    head_token = token.head.text
                    
                    # Adding to the dictionary
                    key_value_pairs[head_token] = value
                    
                    # Increasing number of total_keys founded
                    total_keys += 1
                    
                    if head_token in key_weights:
                        key_weights[head_token] += 1
                    else:
                        key_weights[head_token] = 1
                        
                        
    # Sorting into reverse order 
    key_weights = {k: v for k, v in sorted(key_weights.items(), key=lambda item: item[1], reverse = True)}
    

    # Weight of each key based on frequency of appearance 
    key_weights_percent = {k: f"{round(v/total_keys, 2) * 100}%" for k,v in key_weights.items()}
    
    
    return key_value_pairs, key_weights_percent, key_weights, total_keys


def display_key_value_statistics(key_value_pairs, key_weights_percent, key_weights, total_keys):
    print("NUMERIC KEY/VALUE STATISTICS:")
    print()
    print()
    print(f"Total keys/values: {total_keys}")
    print("-------------------------------------------------------------------------------------------------------")
    print(f"Total unique keys: {len(key_weights_percent)}")
    print("-------------------------------------------------------------------------------------------------------")
    print()
    print()
    print(f"Top 10 key occurrences:")
    print("-------------------------------------------------------------------------------------------------------")
    for key, value in dict(itertools.islice(key_weights.items(), 10)).items():
        print(key, ":", value)
    print()
    print()
    print(f"Top 10 key occurrences in percentage:")
    print("-------------------------------------------------------------------------------------------------------")
    for key, value in dict(itertools.islice(key_weights_percent.items(), 10)).items():
        print(key, ":", value)
    print()
    print()
    
    
    
def key_word_sents(contents, key_word):
    
    """
    
    The Function gets the contents and a key word for numeric value
    and returns its sentences where this key word appears in the contents
    
    """
    
    key_word_sentences = []
    
    for title, content in contents.items():
        
        nlp_content = nlp(content)

        for sent in nlp_content.sents:
            
            for token in sent:
                
                # Finding numeric value
                if token.like_num:
                    
                    if token.head.text == key_word:
                        key_word_sentences.append(sent)
                        
                        
    return key_word_sentences

def display_sentence_dependency(sentences):
    
    for sent in sentences:
        print("Sentence:")
        print("-------------------------------------------------------------------------------------------------------")
        print(sent)
        print()
        print("Sentence Dependency:")
        print("-------------------------------------------------------------------------------------------------------")
        spacy.displacy.render(sent, style='dep', jupyter = True, options = {'distance': 100})
        print()
        print()
        print()
        
        
def relation_entities(contens):
    
    """
    This function gets contens and displays each unique entity's:
        - Relation(label)
        - Dependency(Syntatic dependency)
        - POS(Part-Of-Speech)
    
    """
    seen = set()
    
    # For each content
    for title, content in contens.items():
        
        # for each entity in the content
        for entity in nlp(content).ents:
            
            # Skipping the entity if alreade has been displayed
            if entity.text not in seen:
                print(f"{'Entity:':<12} {entity.text}")
                print(f"{'Relation:':<12} {spacy.explain(entity.label_)}")
                for token in entity:
                    print(f"{'Dependency:':<12} {spacy.explain(token.dep_)}")
                    print(f"{'POS:':<12} {spacy.explain(token.pos_)}")
                    break
                print("-------------------------------------------------------------------------------------------------------")
                print()
                seen.add(entity.text)
                
                
                

                

def event_identification(contents):

    """
    This function iterates over each article and checks,
    whether any of the article covers any specific event or not.
    If there are prints them their title, content, and the sentence where event was found.
    If not prints, that it could not find any event article
    
    """


    event_article = dict()

    # Iterating over each title and content
    for title, content in contents.items():

        nlp_content = nlp2(content)

        # Iterating over each sentence of the given article
        for sent in nlp_content.sents:

            # Assigning each entity label in a list, so we can check whether there are 'DATE' and 'EVENT' entityt
            each_sent_ents = [ent.label_ for ent in sent.ents]

            # Checking for event. If thera assigning its title content and the sentence where 'DATE' and 'EVENT' founded!
            if "DATE" in each_sent_ents and "EVENT" in each_sent_ents:
                event_article[title] = {'content' : nlp_content, 'event sentence': sent}
                break

    # If there are even articles printing them out, else printing no event article found!
    if len(event_article) > 0:
        for title, content in event_article.items():
            print("Event Title:")
            print()
            print(title)
            print("-------------------------------------------------------------------------------------------------------")
            print()
            print()
            print("Event sentence:")
            spacy.displacy.render(content['event sentence'], jupyter=True, style='ent')
            print("-------------------------------------------------------------------------------------------------------")
            print()
            print()
            print("Event content:")
            print()
            spacy.displacy.render(content['content'], jupyter=True, style='ent')

    else:
        print("No Event were found on the Articles!")
        
        
        
def sentiment_analysis(contents):
    
    """
    This function gets each articles paragraphs and prints 
    it's sentiment score using NLTK's VADER sentiment analyser

    """

    for title, content in contents.items():

        print("Title:")
        print(title)
        print("-------------------------------------------------------------------------------------------------------")
        print()

        nlp_content = nlp2(content)
        for sent in nlp_content.sents:
            if len(str(sent).split(" ")) > 2:
                scores = SIA().polarity_scores(str(sent))
                print("Sentence:")
                print("---------")
                print(sent)
                print()
                print("VADER Sentiment Scores:")
                print("-----------------------")
                for str_score, num_score in scores.items():
                    print(f"{str_score}: {num_score}")
                print()
                print()
                print()
